# %% [markdown]
# # Pizza Shop
# You work at a pizza restaurant, which is starting to accept orders online. You need to
# provide a python function that will accept an arbitrary order as its arguments,
# and compute the correct price for the order.
#
# Your cost-calculator function should have four arguments:
# - pizzas
# - drinks
# - wings
# - coupon
#
#
# A single pizza order is formed as a list of toppings. For example
# - A pizza with no toppings (other than cheese and sauce is: [] (an empty list)
# - A pizza with pepperoni and a double order of olives is : ["pepperoni", "olives", "olives"]
#
# *An arbitrary number of pizzas may be ordered, including no pizzas as all*
#
# Drinks come in as a named order (i.e. a keyword argument 'drinks'). If drinks are ordered,
# they are specified as a list of sizes (possible sizes: "small", "medium", "large", "tub"). For example, `drinks=["small", "small", "large"]` would indicate an order including two small drinks and a large drink.
#
# Wings come in as a named order as well (keyword argument 'wings'). If wings are ordered,
# they are specified as a list of integers (possible sizes: 10, 20, 40, 100). For example, `wings=[20]` would indicate a single order of 20-piece wings.
#
# A coupon may be specified as the keyword argument 'coupon'. It is will be a single
# floating point number between 0 and 1. This indicates the fraction of the *pre-tax*
# price that is to be subtracted. For example `coupon=.25` would indicate a 25%-off coupon.
#
# A 6.25% tax is applied to every order. The tax is computed on the total cost of the
# order *before a coupon is applied*
#
# Round the price to the nearest cent, using the built-in function round. `round(x, 2)` will round `x` to two decimal places.
#
# ## Prices
# The prices are as follows:
#
# **Pizza**
# - \$13.00
#
# **Toppings**
# - pepperoni : \$1.00
# - mushroom : \$0.50
# - olive : \$0.50
# - anchovy : \$2.00
# - ham : \$1.50
#
# **Drinks**
# - small : \$2.00
# - medium : \$3.00
# - large : \$3.50
# - tub : \$3.75
#
# **Wings**
# - 10 : \$5.00
# - 20 : \$9.00
# - 40 : \$17.50
# - 100 : \$48.00
#
#
# ## Examples
# The following is an order for a plain pizza, a ham and anchovy pizza, two "tub"-sized
# drinks, with a 10%-off coupon:
# ```python
# >>>cost_calculator([], ["ham", "anchovy"], drinks=["tub", "tub"], coupon=0.1)
# 35.61
# ```
#
# This order consists only of a small drink.
# ```python
# >>> cost_calculator(drinks=["small"])
# 2.12
# ```
#
# This is an order of two plain pizzas, a pizza with double-pepperoni, an order of a 10-piece and a 20-piece wings, and a small drink.
# ```python
# >>> cost_calculator([], [], ["pepperoni", "pepperoni"], wings=[10, 20], drinks=["small"])
# 60.56
# ```
#
# ## Details
# You can assume that the front-end of the website will never pass your function erroneous
# orders. That is, you will never receive orders for items that do not exist nor
# items that contain typos.
#
# Consider defining individual functions responsible for computing
# the cost of the pizzas, drinks, and wings, respectively. Have `cost_calculator`
# invoke these internally. Alternatively, you can read ahead about dictionaries and make nice
# use of these in this problem.
#
# Our `cost_calculator` signature is empty. Part of the assignment is to come up with the
# correct function signature!

# %%
# make sure to execute this cell so that your function is defined
# you must re-run this cell any time you make a change to this function

def cost_calculator(*args, drinks=None, wings=None, coupon=None):
    print(f"args {args}")
    # write your code here
    cost = 0.00
    pizza_cost={
        'pepperoni' : 1.00,
        'mushroom'  : 0.50,
        'olive'     : 0.50,
        'anchovy'   : 2.00,
        'ham'       : 1.50
    }

    # Pizzas
    for pizza in args:
        print(f"Pizza: {pizza}")
        cost+=13 #  plain pizza
        for toping in pizza:
            cost+=pizza_cost.get(toping,0)
    print(f"Pizza Cost: {cost}")
    # drinks
    drink_cost = {
        'small' : 2.00,
        'medium': 3.00,
        'large': 3.50,
        'tub': 3.75,
    }

    print(f"Drinks: {drinks}")
    if drinks is not None: 
        for size in drinks:
            print(f"drink: {size}")
            cost += drink_cost.get(size,0)
        
    

        
    #wings
    wings_cost = {
        10 : 5.00,
        20 : 9.00,
        40 : 17.50,
        100 : 48.00,
    }

    if wings is not None: 
        for wing_type in wings:
            cost += wings_cost.get(wing_type,0)

    discount = 0 if coupon is None else cost * coupon
    
    # tax
    cost += cost * 0.0625
    
    # coupon
    cost -=discount
    
    

    # be sure to include a `return` statement so that
    # your function returns the appropriate object.
    
    return round(cost,2)

# %%
# Execute this cell to grade your work
from bwsi_grader.python.pizza_shop import grader
grader(cost_calculator)
# Out:
# args ([],)
# Pizza: []
# Pizza Cost: 13.0
# Drinks: None
# args ()
# Pizza Cost: 0.0
# Drinks: ['tub']
# drink: tub
# args (['pepperoni'], [])
# Pizza: ['pepperoni']
# Pizza: []
# Pizza Cost: 27.0
# Drinks: None
# args ([], [])
# Pizza: []
# Pizza: []
# Pizza Cost: 26.0
# Drinks: ['tub', 'small']
# drink: tub
# drink: small
# args ()
# Pizza Cost: 0.0
# Drinks: ['large', 'large']
# drink: large
# drink: large
# args (['olive', 'mushroom', 'ham'], ['anchovy', 'mushroom'])
# Pizza: ['olive', 'mushroom', 'ham']
# Pizza: ['anchovy', 'mushroom']
# Pizza Cost: 31.0
# Drinks: ['small', 'small', 'medium']
# drink: small
# drink: small
# drink: medium
# args (['anchovy'], [])
# Pizza: ['anchovy']
# Pizza: []
# Pizza Cost: 28.0
# Drinks: None
# args (['mushroom', 'anchovy'], [])
# Pizza: ['mushroom', 'anchovy']
# Pizza: []
# Pizza Cost: 28.5
# Drinks: ['medium', 'small', 'medium']
# drink: medium
# drink: small
# drink: medium
# args ([], ['pepperoni'], [], ['anchovy', 'pepperoni', 'mushroom'])
# Pizza: []
# Pizza: ['pepperoni']
# Pizza: []
# Pizza: ['anchovy', 'pepperoni', 'mushroom']
# Pizza Cost: 56.5
# Drinks: ['large', 'medium', 'tub']
# drink: large
# drink: medium
# drink: tub
# args ()
# Pizza Cost: 0.0
# Drinks: ['medium', 'medium']
# drink: medium
# drink: medium
# args (['ham'],)
# Pizza: ['ham']
# Pizza Cost: 14.5
# Drinks: ['tub', 'tub']
# drink: tub
# drink: tub
# args (['anchovy', 'mushroom', 'olive'], ['anchovy', 'anchovy'], [], [])
# Pizza: ['anchovy', 'mushroom', 'olive']
# Pizza: ['anchovy', 'anchovy']
# Pizza: []
# Pizza: []
# Pizza Cost: 59.0
# Drinks: ['medium', 'tub']
# drink: medium
# drink: tub
# args (['olive', 'mushroom', 'pepperoni'], ['anchovy'], [])
# Pizza: ['olive', 'mushroom', 'pepperoni']
# Pizza: ['anchovy']
# Pizza: []
# Pizza Cost: 43.0
# Drinks: ['medium']
# drink: medium
# args ()
# Pizza Cost: 0.0
# Drinks: ['medium', 'large']
# drink: medium
# drink: large
# args ()
# Pizza Cost: 0.0
# Drinks: ['small', 'medium', 'tub']
# drink: small
# drink: medium
# drink: tub
# args (['mushroom', 'pepperoni', 'anchovy'], ['mushroom', 'mushroom'])
# Pizza: ['mushroom', 'pepperoni', 'anchovy']
# Pizza: ['mushroom', 'mushroom']
# Pizza Cost: 30.5
# Drinks: ['medium']
# drink: medium
# args (['olive', 'ham', 'mushroom'], ['ham', 'ham'])
# Pizza: ['olive', 'ham', 'mushroom']
# Pizza: ['ham', 'ham']
# Pizza Cost: 31.5
# Drinks: None
# args ([],)
# Pizza: []
# Pizza Cost: 13.0
# Drinks: ['small', 'tub', 'tub']
# drink: small
# drink: tub
# drink: tub
# args ([],)
# Pizza: []
# Pizza Cost: 13.0
# Drinks: ['large', 'large']
# drink: large
# drink: large
# args (['mushroom', 'ham', 'mushroom'],)
# Pizza: ['mushroom', 'ham', 'mushroom']
# Pizza Cost: 15.5
# Drinks: ['small', 'medium', 'tub']
# drink: small
# drink: medium
# drink: tub
# args (['pepperoni', 'anchovy', 'pepperoni'],)
# Pizza: ['pepperoni', 'anchovy', 'pepperoni']
# Pizza Cost: 17.0
# Drinks: ['medium', 'tub', 'large']
# drink: medium
# drink: tub
# drink: large
# args (['anchovy'], [], ['mushroom', 'pepperoni'])
# Pizza: ['anchovy']
# Pizza: []
# Pizza: ['mushroom', 'pepperoni']
# Pizza Cost: 42.5
# Drinks: ['small']
# drink: small
# args (['anchovy', 'mushroom'], ['anchovy', 'mushroom', 'mushroom'])
# Pizza: ['anchovy', 'mushroom']
# Pizza: ['anchovy', 'mushroom', 'mushroom']
# Pizza Cost: 31.5
# Drinks: ['small']
# drink: small
# args (['anchovy', 'anchovy'], ['anchovy', 'pepperoni', 'mushroom'])
# Pizza: ['anchovy', 'anchovy']
# Pizza: ['anchovy', 'pepperoni', 'mushroom']
# Pizza Cost: 33.5
# Drinks: ['large']
# drink: large
# args (['olive'], [])
# Pizza: ['olive']
# Pizza: []
# Pizza Cost: 26.5
# Drinks: ['medium', 'small']
# drink: medium
# drink: small
# args (['ham', 'pepperoni', 'olive'],)
# Pizza: ['ham', 'pepperoni', 'olive']
# Pizza Cost: 16.0
# Drinks: ['small', 'small', 'small']
# drink: small
# drink: small
# drink: small
# args ()
# Pizza Cost: 0.0
# Drinks: ['large', 'tub', 'large']
# drink: large
# drink: tub
# drink: large
# args (['olive', 'ham'], [], ['olive', 'anchovy', 'anchovy'], ['pepperoni'])
# Pizza: ['olive', 'ham']
# Pizza: []
# Pizza: ['olive', 'anchovy', 'anchovy']
# Pizza: ['pepperoni']
# Pizza Cost: 59.5
# Drinks: ['large', 'large', 'tub']
# drink: large
# drink: large
# drink: tub
# args ()
# Pizza Cost: 0.0
# Drinks: ['small', 'medium']
# drink: small
# drink: medium
# args (['pepperoni', 'olive', 'anchovy'], ['olive'])
# Pizza: ['pepperoni', 'olive', 'anchovy']
# Pizza: ['olive']
# Pizza Cost: 30.0
# Drinks: ['tub', 'small', 'tub']
# drink: tub
# drink: small
# drink: tub
# args ([], ['olive'], [])
# Pizza: []
# Pizza: ['olive']
# Pizza: []
# Pizza Cost: 39.5
# Drinks: ['large']
# drink: large
# args (['mushroom', 'mushroom', 'anchovy'], ['pepperoni'], [], ['pepperoni'])
# Pizza: ['mushroom', 'mushroom', 'anchovy']
# Pizza: ['pepperoni']
# Pizza: []
# Pizza: ['pepperoni']
# Pizza Cost: 57.0
# Drinks: ['small', 'tub']
# drink: small
# drink: tub
# args (['olive', 'mushroom', 'mushroom'],)
# Pizza: ['olive', 'mushroom', 'mushroom']
# Pizza Cost: 14.5
# Drinks: None
# args (['ham', 'mushroom'], ['ham', 'olive', 'olive'], ['anchovy'])
# Pizza: ['ham', 'mushroom']
# Pizza: ['ham', 'olive', 'olive']
# Pizza: ['anchovy']
# Pizza Cost: 45.5
# Drinks: None
# args (['pepperoni', 'olive'], ['pepperoni', 'mushroom'])
# Pizza: ['pepperoni', 'olive']
# Pizza: ['pepperoni', 'mushroom']
# Pizza Cost: 29.0
# Drinks: None
# args ([], ['pepperoni', 'ham', 'pepperoni'], ['anchovy', 'pepperoni', 'anchovy'], ['pepperoni', 'pepperoni', 'anchovy'])
# Pizza: []
# Pizza: ['pepperoni', 'ham', 'pepperoni']
# Pizza: ['anchovy', 'pepperoni', 'anchovy']
# Pizza: ['pepperoni', 'pepperoni', 'anchovy']
# Pizza Cost: 64.5
# Drinks: None
# args (['anchovy'], [], ['anchovy', 'anchovy', 'olive'], ['ham', 'anchovy', 'pepperoni'])
# Pizza: ['anchovy']
# Pizza: []
# Pizza: ['anchovy', 'anchovy', 'olive']
# Pizza: ['ham', 'anchovy', 'pepperoni']
# Pizza Cost: 63.0
# Drinks: ['large']
# drink: large
# args (['anchovy', 'pepperoni'], ['mushroom', 'ham'], ['anchovy', 'mushroom', 'anchovy'], ['mushroom'])
# Pizza: ['anchovy', 'pepperoni']
# Pizza: ['mushroom', 'ham']
# Pizza: ['anchovy', 'mushroom', 'anchovy']
# Pizza: ['mushroom']
# Pizza Cost: 62.0
# Drinks: None
# args ()
# Pizza Cost: 0.0
# Drinks: ['small', 'large', 'tub']
# drink: small
# drink: large
# drink: tub
# args (['olive', 'olive', 'mushroom'], ['ham'], ['mushroom'])
# Pizza: ['olive', 'olive', 'mushroom']
# Pizza: ['ham']
# Pizza: ['mushroom']
# Pizza Cost: 42.5
# Drinks: ['large']
# drink: large
# args (['anchovy'], ['ham', 'olive', 'anchovy'], [], [])
# Pizza: ['anchovy']
# Pizza: ['ham', 'olive', 'anchovy']
# Pizza: []
# Pizza: []
# Pizza Cost: 58.0
# Drinks: ['small', 'large', 'medium']
# drink: small
# drink: large
# drink: medium
# args (['ham', 'anchovy', 'olive'],)
# Pizza: ['ham', 'anchovy', 'olive']
# Pizza Cost: 17.0
# Drinks: None
# args (['pepperoni', 'olive', 'ham'], ['anchovy', 'pepperoni', 'mushroom'])
# Pizza: ['pepperoni', 'olive', 'ham']
# Pizza: ['anchovy', 'pepperoni', 'mushroom']
# Pizza Cost: 32.5
# Drinks: ['small', 'large']
# drink: small
# drink: large
# args (['ham', 'pepperoni'], ['ham'])
# Pizza: ['ham', 'pepperoni']
# Pizza: ['ham']
# Pizza Cost: 30.0
# Drinks: ['small']
# drink: small
# args ([], [], ['mushroom', 'pepperoni'], ['pepperoni', 'anchovy'])
# Pizza: []
# Pizza: []
# Pizza: ['mushroom', 'pepperoni']
# Pizza: ['pepperoni', 'anchovy']
# Pizza Cost: 56.5
# Drinks: None
# args (['ham', 'olive', 'mushroom'], [], [])
# Pizza: ['ham', 'olive', 'mushroom']
# Pizza: []
# Pizza: []
# Pizza Cost: 41.5
# Drinks: ['tub', 'medium', 'large']
# drink: tub
# drink: medium
# drink: large
# args ([], ['olive'], [])
# Pizza: []
# Pizza: ['olive']
# Pizza: []
# Pizza Cost: 39.5
# Drinks: ['tub', 'small', 'tub']
# drink: tub
# drink: small
# drink: tub
# args (['mushroom'],)
# Pizza: ['mushroom']
# Pizza Cost: 13.5
# Drinks: ['large']
# drink: large
# args (['mushroom'], ['ham', 'anchovy'], ['olive', 'ham', 'ham'], [])
# Pizza: ['mushroom']
# Pizza: ['ham', 'anchovy']
# Pizza: ['olive', 'ham', 'ham']
# Pizza: []
# Pizza Cost: 59.5
# Drinks: ['large', 'large', 'large']
# drink: large
# drink: large
# drink: large
# args (['ham', 'anchovy', 'pepperoni'], ['ham', 'anchovy'])
# Pizza: ['ham', 'anchovy', 'pepperoni']
# Pizza: ['ham', 'anchovy']
# Pizza Cost: 34.0
# Drinks: ['tub', 'tub']
# drink: tub
# drink: tub
# args ()
# Pizza Cost: 0.0
# Drinks: ['small', 'small', 'small']
# drink: small
# drink: small
# drink: small
# args (['pepperoni'], ['olive', 'pepperoni', 'mushroom'], ['pepperoni', 'mushroom', 'anchovy'], [])
# Pizza: ['pepperoni']
# Pizza: ['olive', 'pepperoni', 'mushroom']
# Pizza: ['pepperoni', 'mushroom', 'anchovy']
# Pizza: []
# Pizza Cost: 58.5
# Drinks: ['small', 'medium']
# drink: small
# drink: medium
# args (['ham', 'mushroom'],)
# Pizza: ['ham', 'mushroom']
# Pizza Cost: 15.0
# Drinks: ['tub', 'small', 'tub']
# drink: tub
# drink: small
# drink: tub
# args (['mushroom'], ['olive', 'pepperoni'], ['pepperoni'])
# Pizza: ['mushroom']
# Pizza: ['olive', 'pepperoni']
# Pizza: ['pepperoni']
# Pizza Cost: 42.0
# Drinks: ['medium', 'tub', 'small']
# drink: medium
# drink: tub
# drink: small
# args ([], ['mushroom', 'mushroom'], [])
# Pizza: []
# Pizza: ['mushroom', 'mushroom']
# Pizza: []
# Pizza Cost: 40.0
# Drinks: ['tub']
# drink: tub
# args (['anchovy', 'anchovy', 'ham'], ['ham', 'pepperoni'])
# Pizza: ['anchovy', 'anchovy', 'ham']
# Pizza: ['ham', 'pepperoni']
# Pizza Cost: 34.0
# Drinks: None
# args (['olive', 'olive'], ['olive'], ['pepperoni', 'olive', 'ham'])
# Pizza: ['olive', 'olive']
# Pizza: ['olive']
# Pizza: ['pepperoni', 'olive', 'ham']
# Pizza Cost: 43.5
# Drinks: None
# args (['anchovy'], ['ham', 'olive', 'ham'], ['olive', 'olive', 'olive'], ['ham', 'pepperoni'])
# Pizza: ['anchovy']
# Pizza: ['ham', 'olive', 'ham']
# Pizza: ['olive', 'olive', 'olive']
# Pizza: ['ham', 'pepperoni']
# Pizza Cost: 61.5
# Drinks: ['tub']
# drink: tub
# args ([], ['ham', 'pepperoni'], [], ['ham', 'mushroom', 'anchovy'])
# Pizza: []
# Pizza: ['ham', 'pepperoni']
# Pizza: []
# Pizza: ['ham', 'mushroom', 'anchovy']
# Pizza Cost: 58.5
# Drinks: ['large', 'large']
# drink: large
# drink: large
# args ()
# Pizza Cost: 0.0
# Drinks: ['tub', 'tub', 'tub']
# drink: tub
# drink: tub
# drink: tub
# args ([], ['olive'], ['anchovy', 'pepperoni', 'ham'], ['pepperoni', 'mushroom'])
# Pizza: []
# Pizza: ['olive']
# Pizza: ['anchovy', 'pepperoni', 'ham']
# Pizza: ['pepperoni', 'mushroom']
# Pizza Cost: 58.5
# Drinks: ['tub', 'tub', 'medium']
# drink: tub
# drink: tub
# drink: medium
# args (['ham'], ['anchovy', 'mushroom'], ['olive', 'ham'], ['anchovy', 'olive', 'ham'])
# Pizza: ['ham']
# Pizza: ['anchovy', 'mushroom']
# Pizza: ['olive', 'ham']
# Pizza: ['anchovy', 'olive', 'ham']
# Pizza Cost: 62.0
# Drinks: None
# args (['anchovy', 'mushroom', 'mushroom'], ['mushroom', 'pepperoni'], ['ham', 'anchovy'], ['pepperoni', 'mushroom'])
# Pizza: ['anchovy', 'mushroom', 'mushroom']
# Pizza: ['mushroom', 'pepperoni']
# Pizza: ['ham', 'anchovy']
# Pizza: ['pepperoni', 'mushroom']
# Pizza Cost: 61.5
# Drinks: ['small', 'tub']
# drink: small
# drink: tub
# args (['mushroom', 'ham'], [], [], [])
# Pizza: ['mushroom', 'ham']
# Pizza: []
# Pizza: []
# Pizza: []
# Pizza Cost: 54.0
# Drinks: None
# args (['mushroom', 'pepperoni', 'mushroom'], ['mushroom', 'ham'], ['ham', 'mushroom', 'ham'], ['ham'])
# Pizza: ['mushroom', 'pepperoni', 'mushroom']
# Pizza: ['mushroom', 'ham']
# Pizza: ['ham', 'mushroom', 'ham']
# Pizza: ['ham']
# Pizza Cost: 61.0
# Drinks: ['medium', 'medium']
# drink: medium
# drink: medium
# args (['ham', 'pepperoni', 'mushroom'], ['pepperoni', 'mushroom'])
# Pizza: ['ham', 'pepperoni', 'mushroom']
# Pizza: ['pepperoni', 'mushroom']
# Pizza Cost: 30.5
# Drinks: ['large']
# drink: large
# args ()
# Pizza Cost: 0.0
# Drinks: None
# args ([], ['pepperoni', 'pepperoni'], [], ['pepperoni', 'mushroom', 'pepperoni'])
# Pizza: []
# Pizza: ['pepperoni', 'pepperoni']
# Pizza: []
# Pizza: ['pepperoni', 'mushroom', 'pepperoni']
# Pizza Cost: 56.5
# Drinks: ['tub', 'small']
# drink: tub
# drink: small
# args (['ham', 'mushroom', 'olive'], ['ham', 'pepperoni', 'ham'], ['olive', 'olive', 'pepperoni'], ['pepperoni', 'mushroom'])
# Pizza: ['ham', 'mushroom', 'olive']
# Pizza: ['ham', 'pepperoni', 'ham']
# Pizza: ['olive', 'olive', 'pepperoni']
# Pizza: ['pepperoni', 'mushroom']
# Pizza Cost: 62.0
# Drinks: ['small']
# drink: small
# args ([],)
# Pizza: []
# Pizza Cost: 13.0
# Drinks: ['small', 'large', 'tub']
# drink: small
# drink: large
# drink: tub
# args ()
# Pizza Cost: 0.0
# Drinks: ['medium', 'small', 'small']
# drink: medium
# drink: small
# drink: small
# args (['mushroom', 'olive'], ['anchovy'])
# Pizza: ['mushroom', 'olive']
# Pizza: ['anchovy']
# Pizza Cost: 29.0
# Drinks: ['large', 'tub']
# drink: large
# drink: tub
# args (['olive', 'ham'],)
# Pizza: ['olive', 'ham']
# Pizza Cost: 15.0
# Drinks: ['tub', 'large', 'large']
# drink: tub
# drink: large
# drink: large
# args (['olive', 'pepperoni'],)
# Pizza: ['olive', 'pepperoni']
# Pizza Cost: 14.5
# Drinks: ['tub']
# drink: tub
# args ()
# Pizza Cost: 0.0
# Drinks: ['medium', 'medium']
# drink: medium
# drink: medium
# args ([], ['mushroom'], ['olive', 'ham'])
# Pizza: []
# Pizza: ['mushroom']
# Pizza: ['olive', 'ham']
# Pizza Cost: 41.5
# Drinks: ['large', 'tub']
# drink: large
# drink: tub
# args (['pepperoni'], ['olive'], ['olive', 'mushroom', 'pepperoni'])
# Pizza: ['pepperoni']
# Pizza: ['olive']
# Pizza: ['olive', 'mushroom', 'pepperoni']
# Pizza Cost: 42.5
# Drinks: ['large']
# drink: large
# args ()
# Pizza Cost: 0.0
# Drinks: ['tub', 'tub', 'large']
# drink: tub
# drink: tub
# drink: large
# args (['anchovy', 'anchovy', 'pepperoni'], ['ham', 'ham'])
# Pizza: ['anchovy', 'anchovy', 'pepperoni']
# Pizza: ['ham', 'ham']
# Pizza Cost: 34.0
# Drinks: ['tub', 'tub']
# drink: tub
# drink: tub
# args ([],)
# Pizza: []
# Pizza Cost: 13.0
# Drinks: ['large', 'medium', 'large']
# drink: large
# drink: medium
# drink: large
# args (['olive', 'olive'],)
# Pizza: ['olive', 'olive']
# Pizza Cost: 14.0
# Drinks: None
# args ([], ['pepperoni'], ['ham'])
# Pizza: []
# Pizza: ['pepperoni']
# Pizza: ['ham']
# Pizza Cost: 41.5
# Drinks: None
# args (['pepperoni', 'mushroom'], [])
# Pizza: ['pepperoni', 'mushroom']
# Pizza: []
# Pizza Cost: 27.5
# Drinks: None
# args ()
# Pizza Cost: 0.0
# Drinks: ['tub']
# drink: tub
# args ([], ['ham'], ['mushroom', 'anchovy', 'mushroom'])
# Pizza: []
# Pizza: ['ham']
# Pizza: ['mushroom', 'anchovy', 'mushroom']
# Pizza Cost: 43.5
# Drinks: ['medium', 'medium']
# drink: medium
# drink: medium
# args (['ham'],)
# Pizza: ['ham']
# Pizza Cost: 14.5
# Drinks: ['small', 'small', 'small']
# drink: small
# drink: small
# drink: small
# args ([], ['ham', 'mushroom'], [])
# Pizza: []
# Pizza: ['ham', 'mushroom']
# Pizza: []
# Pizza Cost: 41.0
# Drinks: ['medium', 'small']
# drink: medium
# drink: small
# args ([],)
# Pizza: []
# Pizza Cost: 13.0
# Drinks: ['medium', 'large']
# drink: medium
# drink: large
# args (['anchovy', 'ham'], ['mushroom', 'mushroom', 'olive'])
# Pizza: ['anchovy', 'ham']
# Pizza: ['mushroom', 'mushroom', 'olive']
# Pizza Cost: 31.0
# Drinks: ['medium', 'small']
# drink: medium
# drink: small
# args (['olive'], [])
# Pizza: ['olive']
# Pizza: []
# Pizza Cost: 26.5
# Drinks: ['small', 'large', 'small']
# drink: small
# drink: large
# drink: small
# args (['ham', 'olive', 'pepperoni'], [], ['olive'])
# Pizza: ['ham', 'olive', 'pepperoni']
# Pizza: []
# Pizza: ['olive']
# Pizza Cost: 42.5
# Drinks: ['medium', 'small']
# drink: medium
# drink: small
# args (['anchovy', 'mushroom', 'mushroom'], [])
# Pizza: ['anchovy', 'mushroom', 'mushroom']
# Pizza: []
# Pizza Cost: 29.0
# Drinks: ['tub', 'tub', 'small']
# drink: tub
# drink: tub
# drink: small
# args ()
# Pizza Cost: 0.0
# Drinks: ['tub', 'medium']
# drink: tub
# drink: medium
# args ([], ['ham', 'anchovy'], ['ham', 'pepperoni', 'pepperoni'])
# Pizza: []
# Pizza: ['ham', 'anchovy']
# Pizza: ['ham', 'pepperoni', 'pepperoni']
# Pizza Cost: 46.0
# Drinks: ['medium', 'tub']
# drink: medium
# drink: tub
# args ()
# Pizza Cost: 0.0
# Drinks: None
# args ()
# Pizza Cost: 0.0
# Drinks: None
# args (['pepperoni', 'mushroom'], ['anchovy', 'anchovy', 'olive'], ['ham', 'mushroom'])
# Pizza: ['pepperoni', 'mushroom']
# Pizza: ['anchovy', 'anchovy', 'olive']
# Pizza: ['ham', 'mushroom']
# Pizza Cost: 47.0
# Drinks: None
# args ()
# Pizza Cost: 0.0
# Drinks: ['medium']
# drink: medium
# args ()
# Pizza Cost: 0.0
# Drinks: ['medium', 'medium', 'tub']
# drink: medium
# drink: medium
# drink: tub
# args (['anchovy', 'anchovy', 'pepperoni'],)
# Pizza: ['anchovy', 'anchovy', 'pepperoni']
# Pizza Cost: 18.0
# Drinks: ['large', 'tub']
# drink: large
# drink: tub
# args ()
# Pizza Cost: 0.0
# Drinks: ['large', 'large']
# drink: large
# drink: large
# args (['ham'], [], ['olive'])
# Pizza: ['ham']
# Pizza: []
# Pizza: ['olive']
# Pizza Cost: 41.0
# Drinks: None
# args (['pepperoni'], ['pepperoni', 'anchovy'], ['pepperoni', 'pepperoni', 'ham'])
# Pizza: ['pepperoni']
# Pizza: ['pepperoni', 'anchovy']
# Pizza: ['pepperoni', 'pepperoni', 'ham']
# Pizza Cost: 46.5
# Drinks: ['large']
# drink: large
# args (['mushroom', 'pepperoni'], ['ham', 'pepperoni', 'ham'])
# Pizza: ['mushroom', 'pepperoni']
# Pizza: ['ham', 'pepperoni', 'ham']
# Pizza Cost: 31.5
# Drinks: ['large', 'medium']
# drink: large
# drink: medium
# args ()
# Pizza Cost: 0.0
# Drinks: ['medium']
# drink: medium
# args (['pepperoni', 'anchovy'], [])
# Pizza: ['pepperoni', 'anchovy']
# Pizza: []
# Pizza Cost: 29.0
# Drinks: None
# args (['ham', 'anchovy', 'ham'],)
# Pizza: ['ham', 'anchovy', 'ham']
# Pizza Cost: 18.0
# Drinks: ['large', 'large']
# drink: large
# drink: large
# args ([],)
# Pizza: []
# Pizza Cost: 13.0
# Drinks: ['tub', 'tub']
# drink: tub
# drink: tub
# args (['pepperoni', 'pepperoni', 'ham'], ['ham'])
# Pizza: ['pepperoni', 'pepperoni', 'ham']
# Pizza: ['ham']
# Pizza Cost: 31.0
# Drinks: ['large', 'large', 'small']
# drink: large
# drink: large
# drink: small
# args ()
# Pizza Cost: 0.0
# Drinks: None
# args ([], [])
# Pizza: []
# Pizza: []
# Pizza Cost: 26.0
# Drinks: ['small', 'small']
# drink: small
# drink: small
# args ()
# Pizza Cost: 0.0
# Drinks: ['small', 'large']
# drink: small
# drink: large
# args ([], ['pepperoni', 'pepperoni'], [])
# Pizza: []
# Pizza: ['pepperoni', 'pepperoni']
# Pizza: []
# Pizza Cost: 41.0
# Drinks: ['large', 'medium']
# drink: large
# drink: medium
# args ()
# Pizza Cost: 0.0
# Drinks: ['small']
# drink: small
# args ()
# Pizza Cost: 0.0
# Drinks: ['medium', 'small', 'medium']
# drink: medium
# drink: small
# drink: medium
# args (['olive'], ['mushroom', 'olive'])
# Pizza: ['olive']
# Pizza: ['mushroom', 'olive']
# Pizza Cost: 27.5
# Drinks: None
# args (['ham', 'olive', 'mushroom'], ['anchovy'], ['pepperoni'])
# Pizza: ['ham', 'olive', 'mushroom']
# Pizza: ['anchovy']
# Pizza: ['pepperoni']
# Pizza Cost: 44.5
# Drinks: ['medium', 'medium']
# drink: medium
# drink: medium
# args ([], ['olive', 'olive', 'olive'], ['olive'])
# Pizza: []
# Pizza: ['olive', 'olive', 'olive']
# Pizza: ['olive']
# Pizza Cost: 41.0
# Drinks: ['large']
# drink: large
# args (['ham', 'anchovy', 'pepperoni'], [], ['mushroom', 'pepperoni'], ['ham'])
# Pizza: ['ham', 'anchovy', 'pepperoni']
# Pizza: []
# Pizza: ['mushroom', 'pepperoni']
# Pizza: ['ham']
# Pizza Cost: 59.5
# Drinks: ['large']
# drink: large
# args (['mushroom'], [])
# Pizza: ['mushroom']
# Pizza: []
# Pizza Cost: 26.5
# Drinks: ['tub', 'medium', 'medium']
# drink: tub
# drink: medium
# drink: medium
# args (['mushroom'], ['pepperoni', 'olive'])
# Pizza: ['mushroom']
# Pizza: ['pepperoni', 'olive']
# Pizza Cost: 28.0
# Drinks: None
# args ([], ['ham', 'ham', 'mushroom'], ['ham', 'ham', 'mushroom'], ['ham', 'pepperoni'])
# Pizza: []
# Pizza: ['ham', 'ham', 'mushroom']
# Pizza: ['ham', 'ham', 'mushroom']
# Pizza: ['ham', 'pepperoni']
# Pizza Cost: 61.5
# Drinks: ['tub', 'large', 'tub']
# drink: tub
# drink: large
# drink: tub
# args (['olive', 'mushroom'], ['ham', 'pepperoni', 'olive'])
# Pizza: ['olive', 'mushroom']
# Pizza: ['ham', 'pepperoni', 'olive']
# Pizza Cost: 30.0
# Drinks: None
# args (['pepperoni'], ['anchovy'], ['ham'], [])
# Pizza: ['pepperoni']
# Pizza: ['anchovy']
# Pizza: ['ham']
# Pizza: []
# Pizza Cost: 56.5
# Drinks: ['tub', 'medium']
# drink: tub
# drink: medium
# args ()
# Pizza Cost: 0.0
# Drinks: None
# args (['anchovy', 'anchovy', 'anchovy'], ['olive', 'ham'])
# Pizza: ['anchovy', 'anchovy', 'anchovy']
# Pizza: ['olive', 'ham']
# Pizza Cost: 34.0
# Drinks: None
# args ()
# Pizza Cost: 0.0
# Drinks: None
# args ([], ['pepperoni'])
# Pizza: []
# Pizza: ['pepperoni']
# Pizza Cost: 27.0
# Drinks: ['large']
# drink: large
# args ([], ['ham', 'olive', 'anchovy'], [], ['anchovy'])
# Pizza: []
# Pizza: ['ham', 'olive', 'anchovy']
# Pizza: []
# Pizza: ['anchovy']
# Pizza Cost: 58.0
# Drinks: ['tub']
# drink: tub
# args ()
# Pizza Cost: 0.0
# Drinks: ['small', 'medium', 'small']
# drink: small
# drink: medium
# drink: small
# args (['ham', 'anchovy'],)
# Pizza: ['ham', 'anchovy']
# Pizza Cost: 16.5
# Drinks: ['large', 'large', 'medium']
# drink: large
# drink: large
# drink: medium
# args (['mushroom'], [])
# Pizza: ['mushroom']
# Pizza: []
# Pizza Cost: 26.5
# Drinks: ['medium']
# drink: medium
# args (['ham', 'ham', 'anchovy'], ['anchovy', 'pepperoni'])
# Pizza: ['ham', 'ham', 'anchovy']
# Pizza: ['anchovy', 'pepperoni']
# Pizza Cost: 34.0
# Drinks: ['large', 'tub']
# drink: large
# drink: tub
# args (['ham', 'ham'], ['mushroom'])
# Pizza: ['ham', 'ham']
# Pizza: ['mushroom']
# Pizza Cost: 29.5
# Drinks: ['large', 'small']
# drink: large
# drink: small
# args (['mushroom'],)
# Pizza: ['mushroom']
# Pizza Cost: 13.5
# Drinks: ['tub']
# drink: tub
# args ()
# Pizza Cost: 0.0
# Drinks: ['small']
# drink: small
# args ([],)
# Pizza: []
# Pizza Cost: 13.0
# Drinks: ['large']
# drink: large
# args (['ham', 'olive', 'olive'],)
# Pizza: ['ham', 'olive', 'olive']
# Pizza Cost: 15.5
# Drinks: ['tub']
# drink: tub
# args ()
# Pizza Cost: 0.0
# Drinks: ['large']
# drink: large
# args ()
# Pizza Cost: 0.0
# Drinks: ['small', 'tub']
# drink: small
# drink: tub
# args (['anchovy', 'mushroom', 'mushroom'], ['mushroom'])
# Pizza: ['anchovy', 'mushroom', 'mushroom']
# Pizza: ['mushroom']
# Pizza Cost: 29.5
# Drinks: ['medium']
# drink: medium
# args (['pepperoni', 'mushroom'], ['olive', 'ham', 'anchovy'], ['ham', 'mushroom', 'ham'])
# Pizza: ['pepperoni', 'mushroom']
# Pizza: ['olive', 'ham', 'anchovy']
# Pizza: ['ham', 'mushroom', 'ham']
# Pizza Cost: 48.0
# Drinks: ['small']
# drink: small
# args ()
# Pizza Cost: 0.0
# Drinks: ['large', 'medium']
# drink: large
# drink: medium
# args (['mushroom', 'pepperoni'], ['pepperoni'], ['olive'], ['ham', 'pepperoni', 'mushroom'])
# Pizza: ['mushroom', 'pepperoni']
# Pizza: ['pepperoni']
# Pizza: ['olive']
# Pizza: ['ham', 'pepperoni', 'mushroom']
# Pizza Cost: 58.0
# Drinks: ['small', 'medium']
# drink: small
# drink: medium
# args ([], ['mushroom', 'olive'])
# Pizza: []
# Pizza: ['mushroom', 'olive']
# Pizza Cost: 27.0
# Drinks: None
# args ([], ['mushroom', 'pepperoni'], [])
# Pizza: []
# Pizza: ['mushroom', 'pepperoni']
# Pizza: []
# Pizza Cost: 40.5
# Drinks: None
# args (['anchovy', 'anchovy', 'ham'], ['olive'])
# Pizza: ['anchovy', 'anchovy', 'ham']
# Pizza: ['olive']
# Pizza Cost: 32.0
# Drinks: ['tub', 'small']
# drink: tub
# drink: small
# args (['pepperoni'],)
# Pizza: ['pepperoni']
# Pizza Cost: 14.0
# Drinks: None
# args ([], ['anchovy', 'pepperoni', 'ham'], [], ['ham', 'anchovy'])
# Pizza: []
# Pizza: ['anchovy', 'pepperoni', 'ham']
# Pizza: []
# Pizza: ['ham', 'anchovy']
# Pizza Cost: 60.0
# Drinks: None
# args ()
# Pizza Cost: 0.0
# Drinks: None
# args ()
# Pizza Cost: 0.0
# Drinks: None
# args (['pepperoni', 'ham'],)
# Pizza: ['pepperoni', 'ham']
# Pizza Cost: 15.5
# Drinks: None
# args (['ham', 'mushroom', 'anchovy'],)
# Pizza: ['ham', 'mushroom', 'anchovy']
# Pizza Cost: 17.0
# Drinks: None
# args (['mushroom', 'olive', 'olive'], ['ham'], ['pepperoni'])
# Pizza: ['mushroom', 'olive', 'olive']
# Pizza: ['ham']
# Pizza: ['pepperoni']
# Pizza Cost: 43.0
# Drinks: ['medium', 'tub']
# drink: medium
# drink: tub
# args ([], ['mushroom', 'anchovy', 'ham'])
# Pizza: []
# Pizza: ['mushroom', 'anchovy', 'ham']
# Pizza Cost: 30.0
# Drinks: ['small', 'tub', 'tub']
# drink: small
# drink: tub
# drink: tub
# args ([], ['anchovy'], ['mushroom', 'olive', 'pepperoni'], ['anchovy'])
# Pizza: []
# Pizza: ['anchovy']
# Pizza: ['mushroom', 'olive', 'pepperoni']
# Pizza: ['anchovy']
# Pizza Cost: 58.0
# Drinks: ['small', 'small', 'tub']
# drink: small
# drink: small
# drink: tub
# args (['pepperoni', 'olive', 'olive'],)
# Pizza: ['pepperoni', 'olive', 'olive']
# Pizza Cost: 15.0
# Drinks: None
# args ()
# Pizza Cost: 0.0
# Drinks: ['large', 'tub']
# drink: large
# drink: tub
# args (['olive', 'anchovy', 'anchovy'], ['olive', 'mushroom'], ['anchovy', 'olive', 'olive'])
# Pizza: ['olive', 'anchovy', 'anchovy']
# Pizza: ['olive', 'mushroom']
# Pizza: ['anchovy', 'olive', 'olive']
# Pizza Cost: 47.5
# Drinks: ['tub', 'large']
# drink: tub
# drink: large
# args (['ham'], ['olive', 'olive'], ['mushroom'], ['ham'])
# Pizza: ['ham']
# Pizza: ['olive', 'olive']
# Pizza: ['mushroom']
# Pizza: ['ham']
# Pizza Cost: 56.5
# Drinks: ['medium', 'medium', 'tub']
# drink: medium
# drink: medium
# drink: tub
# args ([], ['ham'])
# Pizza: []
# Pizza: ['ham']
# Pizza Cost: 27.5
# Drinks: ['large', 'medium']
# drink: large
# drink: medium
# args (['olive', 'anchovy'], [], [])
# Pizza: ['olive', 'anchovy']
# Pizza: []
# Pizza: []
# Pizza Cost: 41.5
# Drinks: ['large', 'small']
# drink: large
# drink: small
# args (['ham'], ['mushroom', 'anchovy'])
# Pizza: ['ham']
# Pizza: ['mushroom', 'anchovy']
# Pizza Cost: 30.0
# Drinks: None
# args ()
# Pizza Cost: 0.0
# Drinks: ['medium']
# drink: medium
# args ()
# Pizza Cost: 0.0
# Drinks: None
# args (['mushroom', 'olive', 'olive'], ['ham'])
# Pizza: ['mushroom', 'olive', 'olive']
# Pizza: ['ham']
# Pizza Cost: 29.0
# Drinks: ['large', 'large']
# drink: large
# drink: large
# args ([],)
# Pizza: []
# Pizza Cost: 13.0
# Drinks: ['small']
# drink: small
# args (['olive', 'ham'], ['anchovy', 'olive', 'ham'])
# Pizza: ['olive', 'ham']
# Pizza: ['anchovy', 'olive', 'ham']
# Pizza Cost: 32.0
# Drinks: ['medium', 'tub']
# drink: medium
# drink: tub
# args ()
# Pizza Cost: 0.0
# Drinks: ['tub', 'medium', 'tub']
# drink: tub
# drink: medium
# drink: tub
# args (['olive', 'anchovy', 'ham'], [], ['mushroom', 'mushroom', 'mushroom'])
# Pizza: ['olive', 'anchovy', 'ham']
# Pizza: []
# Pizza: ['mushroom', 'mushroom', 'mushroom']
# Pizza Cost: 44.5
# Drinks: ['tub', 'tub', 'medium']
# drink: tub
# drink: tub
# drink: medium
# args (['ham', 'mushroom'], ['pepperoni', 'pepperoni'], [])
# Pizza: ['ham', 'mushroom']
# Pizza: ['pepperoni', 'pepperoni']
# Pizza: []
# Pizza Cost: 43.0
# Drinks: ['large', 'small']
# drink: large
# drink: small
# args (['mushroom', 'ham', 'ham'], ['ham'])
# Pizza: ['mushroom', 'ham', 'ham']
# Pizza: ['ham']
# Pizza Cost: 31.0
# Drinks: None
# args (['olive', 'ham', 'anchovy'],)
# Pizza: ['olive', 'ham', 'anchovy']
# Pizza Cost: 17.0
# Drinks: ['small']
# drink: small
# args ([], ['anchovy', 'mushroom', 'olive'], [], ['anchovy'])
# Pizza: []
# Pizza: ['anchovy', 'mushroom', 'olive']
# Pizza: []
# Pizza: ['anchovy']
# Pizza Cost: 57.0
# Drinks: ['small', 'large']
# drink: small
# drink: large
# args (['pepperoni'],)
# Pizza: ['pepperoni']
# Pizza Cost: 14.0
# Drinks: ['small']
# drink: small
# args ([], ['olive'], ['olive', 'pepperoni'])
# Pizza: []
# Pizza: ['olive']
# Pizza: ['olive', 'pepperoni']
# Pizza Cost: 41.0
# Drinks: None
# args (['olive', 'pepperoni', 'ham'], ['pepperoni'], ['pepperoni'], ['olive', 'mushroom', 'ham'])
# Pizza: ['olive', 'pepperoni', 'ham']
# Pizza: ['pepperoni']
# Pizza: ['pepperoni']
# Pizza: ['olive', 'mushroom', 'ham']
# Pizza Cost: 59.5
# Drinks: ['tub', 'tub']
# drink: tub
# drink: tub
# args (['anchovy'],)
# Pizza: ['anchovy']
# Pizza Cost: 15.0
# Drinks: ['large', 'medium', 'large']
# drink: large
# drink: medium
# drink: large
# args ([], ['ham'], ['olive', 'pepperoni'], ['ham', 'mushroom', 'mushroom'])
# Pizza: []
# Pizza: ['ham']
# Pizza: ['olive', 'pepperoni']
# Pizza: ['ham', 'mushroom', 'mushroom']
# Pizza Cost: 57.5
# Drinks: ['tub']
# drink: tub
# args (['mushroom', 'pepperoni'], [])
# Pizza: ['mushroom', 'pepperoni']
# Pizza: []
# Pizza Cost: 27.5
# Drinks: ['small']
# drink: small
# args ([], ['anchovy', 'ham', 'anchovy'], ['olive', 'anchovy', 'olive'])
# Pizza: []
# Pizza: ['anchovy', 'ham', 'anchovy']
# Pizza: ['olive', 'anchovy', 'olive']
# Pizza Cost: 47.5
# Drinks: None
# args ()
# Pizza Cost: 0.0
# Drinks: ['medium', 'large', 'medium']
# drink: medium
# drink: large
# drink: medium
# args ()
# Pizza Cost: 0.0
# Drinks: ['small', 'medium']
# drink: small
# drink: medium
# args ()
# Pizza Cost: 0.0
# Drinks: ['large', 'large', 'small']
# drink: large
# drink: large
# drink: small
# args (['pepperoni', 'ham'], ['anchovy', 'olive'], ['mushroom', 'olive', 'mushroom'])
# Pizza: ['pepperoni', 'ham']
# Pizza: ['anchovy', 'olive']
# Pizza: ['mushroom', 'olive', 'mushroom']
# Pizza Cost: 45.5
# Drinks: ['tub', 'small', 'small']
# drink: tub
# drink: small
# drink: small
# args ()
# Pizza Cost: 0.0
# Drinks: ['large', 'large']
# drink: large
# drink: large
# args (['ham', 'ham'], ['pepperoni', 'anchovy'])
# Pizza: ['ham', 'ham']
# Pizza: ['pepperoni', 'anchovy']
# Pizza Cost: 32.0
# Drinks: ['small', 'large']
# drink: small
# drink: large
# args (['olive', 'anchovy', 'olive'], ['ham', 'olive'], ['mushroom', 'ham', 'olive'], ['olive', 'ham'])
# Pizza: ['olive', 'anchovy', 'olive']
# Pizza: ['ham', 'olive']
# Pizza: ['mushroom', 'ham', 'olive']
# Pizza: ['olive', 'ham']
# Pizza Cost: 61.5
# Drinks: ['large', 'small']
# drink: large
# drink: small
# args (['ham', 'anchovy'],)
# Pizza: ['ham', 'anchovy']
# Pizza Cost: 16.5
# Drinks: ['small']
# drink: small
# args (['ham'],)
# Pizza: ['ham']
# Pizza Cost: 14.5
# Drinks: ['small', 'small', 'small']
# drink: small
# drink: small
# drink: small
# args (['olive', 'mushroom'], ['ham', 'mushroom'], ['ham', 'pepperoni', 'mushroom'])
# Pizza: ['olive', 'mushroom']
# Pizza: ['ham', 'mushroom']
# Pizza: ['ham', 'pepperoni', 'mushroom']
# Pizza Cost: 45.0
# Drinks: ['large', 'medium']
# drink: large
# drink: medium
# args (['mushroom', 'ham', 'pepperoni'], [], [], ['ham'])
# Pizza: ['mushroom', 'ham', 'pepperoni']
# Pizza: []
# Pizza: []
# Pizza: ['ham']
# Pizza Cost: 56.5
# Drinks: ['medium', 'tub', 'small']
# drink: medium
# drink: tub
# drink: small
# args ()
# Pizza Cost: 0.0
# Drinks: ['large', 'large', 'small']
# drink: large
# drink: large
# drink: small
# args (['olive'], ['anchovy'])
# Pizza: ['olive']
# Pizza: ['anchovy']
# Pizza Cost: 28.5
# Drinks: ['large']
# drink: large
# args ()
# Pizza Cost: 0.0
# Drinks: ['tub', 'large', 'medium']
# drink: tub
# drink: large
# drink: medium
# args ([], ['olive'], ['mushroom', 'ham'], ['olive', 'olive', 'ham'])
# Pizza: []
# Pizza: ['olive']
# Pizza: ['mushroom', 'ham']
# Pizza: ['olive', 'olive', 'ham']
# Pizza Cost: 57.0
# Drinks: ['large', 'medium', 'tub']
# drink: large
# drink: medium
# drink: tub
# args ([], ['mushroom'], ['ham', 'ham'])
# Pizza: []
# Pizza: ['mushroom']
# Pizza: ['ham', 'ham']
# Pizza Cost: 42.5
# Drinks: None
# args ()
# Pizza Cost: 0.0
# Drinks: ['tub', 'medium']
# drink: tub
# drink: medium
# args (['pepperoni', 'mushroom', 'mushroom'], ['mushroom', 'olive'])
# Pizza: ['pepperoni', 'mushroom', 'mushroom']
# Pizza: ['mushroom', 'olive']
# Pizza Cost: 29.0
# Drinks: None
# args (['pepperoni', 'mushroom'], [], ['anchovy', 'olive', 'pepperoni'], ['anchovy'])
# Pizza: ['pepperoni', 'mushroom']
# Pizza: []
# Pizza: ['anchovy', 'olive', 'pepperoni']
# Pizza: ['anchovy']
# Pizza Cost: 59.0
# Drinks: ['large', 'medium']
# drink: large
# drink: medium
# args ()
# Pizza Cost: 0.0
# Drinks: ['tub']
# drink: tub
# args ([], ['ham', 'ham', 'mushroom'], ['pepperoni', 'mushroom'], ['pepperoni'])
# Pizza: []
# Pizza: ['ham', 'ham', 'mushroom']
# Pizza: ['pepperoni', 'mushroom']
# Pizza: ['pepperoni']
# Pizza Cost: 58.0
# Drinks: ['small', 'small', 'large']
# drink: small
# drink: small
# drink: large
# args ([],)
# Pizza: []
# Pizza Cost: 13.0
# Drinks: ['small']
# drink: small
# args ([], ['mushroom'], ['ham', 'pepperoni', 'anchovy'], ['mushroom', 'anchovy'])
# Pizza: []
# Pizza: ['mushroom']
# Pizza: ['ham', 'pepperoni', 'anchovy']
# Pizza: ['mushroom', 'anchovy']
# Pizza Cost: 59.5
# Drinks: ['large', 'small', 'tub']
# drink: large
# drink: small
# drink: tub
# args (['mushroom', 'mushroom'],)
# Pizza: ['mushroom', 'mushroom']
# Pizza Cost: 14.0
# Drinks: ['small', 'large']
# drink: small
# drink: large
# args ([], ['pepperoni', 'mushroom'])
# Pizza: []
# Pizza: ['pepperoni', 'mushroom']
# Pizza Cost: 27.5
# Drinks: ['tub', 'large']
# drink: tub
# drink: large
# args (['pepperoni'], ['anchovy', 'mushroom'], ['pepperoni', 'mushroom'], ['mushroom', 'ham'])
# Pizza: ['pepperoni']
# Pizza: ['anchovy', 'mushroom']
# Pizza: ['pepperoni', 'mushroom']
# Pizza: ['mushroom', 'ham']
# Pizza Cost: 59.0
# Drinks: ['medium', 'medium', 'tub']
# drink: medium
# drink: medium
# drink: tub
# args ()
# Pizza Cost: 0.0
# Drinks: None
# args (['mushroom', 'mushroom', 'pepperoni'],)
# Pizza: ['mushroom', 'mushroom', 'pepperoni']
# Pizza Cost: 15.0
# Drinks: None
# args ([],)
# Pizza: []
# Pizza Cost: 13.0
# Drinks: ['medium', 'large', 'tub']
# drink: medium
# drink: large
# drink: tub
# args (['ham', 'pepperoni', 'pepperoni'], ['pepperoni'], ['ham', 'ham', 'pepperoni'])
# Pizza: ['ham', 'pepperoni', 'pepperoni']
# Pizza: ['pepperoni']
# Pizza: ['ham', 'ham', 'pepperoni']
# Pizza Cost: 47.5
# Drinks: ['large']
# drink: large
# args ([], [], ['mushroom'])
# Pizza: []
# Pizza: []
# Pizza: ['mushroom']
# Pizza Cost: 39.5
# Drinks: ['small']
# drink: small
# args (['anchovy', 'ham'], ['pepperoni', 'mushroom'])
# Pizza: ['anchovy', 'ham']
# Pizza: ['pepperoni', 'mushroom']
# Pizza Cost: 31.0
# Drinks: ['large', 'tub']
# drink: large
# drink: tub
# args (['anchovy', 'mushroom'],)
# Pizza: ['anchovy', 'mushroom']
# Pizza Cost: 15.5
# Drinks: ['small', 'medium', 'tub']
# drink: small
# drink: medium
# drink: tub
# args (['olive', 'olive'], [], ['anchovy'])
# Pizza: ['olive', 'olive']
# Pizza: []
# Pizza: ['anchovy']
# Pizza Cost: 42.0
# Drinks: None
# args (['olive'], ['olive', 'pepperoni'], ['anchovy'])
# Pizza: ['olive']
# Pizza: ['olive', 'pepperoni']
# Pizza: ['anchovy']
# Pizza Cost: 43.0
# Drinks: ['medium', 'large', 'large']
# drink: medium
# drink: large
# drink: large
# args (['ham', 'ham'], ['anchovy', 'olive', 'anchovy'])
# Pizza: ['ham', 'ham']
# Pizza: ['anchovy', 'olive', 'anchovy']
# Pizza Cost: 33.5
# Drinks: ['small', 'medium', 'tub']
# drink: small
# drink: medium
# drink: tub
# args ()
# Pizza Cost: 0.0
# Drinks: ['large', 'small', 'small']
# drink: large
# drink: small
# drink: small
# args (['ham', 'mushroom', 'anchovy'], ['olive', 'ham'])
# Pizza: ['ham', 'mushroom', 'anchovy']
# Pizza: ['olive', 'ham']
# Pizza Cost: 32.0
# Drinks: ['large', 'small', 'small']
# drink: large
# drink: small
# drink: small
# args (['anchovy'],)
# Pizza: ['anchovy']
# Pizza Cost: 15.0
# Drinks: ['large']
# drink: large
# args ([], ['anchovy', 'pepperoni'], ['mushroom', 'olive'])
# Pizza: []
# Pizza: ['anchovy', 'pepperoni']
# Pizza: ['mushroom', 'olive']
# Pizza Cost: 43.0
# Drinks: ['medium', 'large', 'tub']
# drink: medium
# drink: large
# drink: tub
# args ([],)
# Pizza: []
# Pizza Cost: 13.0
# Drinks: ['medium']
# drink: medium
# args ()
# Pizza Cost: 0.0
# Drinks: ['medium', 'small']
# drink: medium
# drink: small
# args ()
# Pizza Cost: 0.0
# Drinks: ['medium', 'large']
# drink: medium
# drink: large
# args (['mushroom', 'ham', 'ham'],)
# Pizza: ['mushroom', 'ham', 'ham']
# Pizza Cost: 16.5
# Drinks: None
# args (['mushroom', 'mushroom', 'olive'],)
# Pizza: ['mushroom', 'mushroom', 'olive']
# Pizza Cost: 14.5
# Drinks: ['large', 'small']
# drink: large
# drink: small
# args (['mushroom'], [], ['mushroom'], ['mushroom', 'mushroom', 'pepperoni'])
# Pizza: ['mushroom']
# Pizza: []
# Pizza: ['mushroom']
# Pizza: ['mushroom', 'mushroom', 'pepperoni']
# Pizza Cost: 55.0
# Drinks: None
# args (['pepperoni', 'ham', 'pepperoni'],)
# Pizza: ['pepperoni', 'ham', 'pepperoni']
# Pizza Cost: 16.5
# Drinks: ['medium', 'large', 'small']
# drink: medium
# drink: large
# drink: small
# args (['mushroom', 'anchovy', 'mushroom'],)
# Pizza: ['mushroom', 'anchovy', 'mushroom']
# Pizza Cost: 16.0
# Drinks: None
# args (['ham', 'mushroom', 'pepperoni'], ['olive'])
# Pizza: ['ham', 'mushroom', 'pepperoni']
# Pizza: ['olive']
# Pizza Cost: 29.5
# Drinks: ['large']
# drink: large
# args (['mushroom', 'anchovy'], ['anchovy', 'olive', 'mushroom'], ['pepperoni'])
# Pizza: ['mushroom', 'anchovy']
# Pizza: ['anchovy', 'olive', 'mushroom']
# Pizza: ['pepperoni']
# Pizza Cost: 45.5
# Drinks: ['tub']
# drink: tub
# args (['ham', 'pepperoni', 'mushroom'],)
# Pizza: ['ham', 'pepperoni', 'mushroom']
# Pizza Cost: 16.0
# Drinks: None
# args ([],)
# Pizza: []
# Pizza Cost: 13.0
# Drinks: ['small']
# drink: small
# args ([], ['mushroom', 'pepperoni'], ['ham', 'mushroom'], ['ham', 'olive'])
# Pizza: []
# Pizza: ['mushroom', 'pepperoni']
# Pizza: ['ham', 'mushroom']
# Pizza: ['ham', 'olive']
# Pizza Cost: 57.5
# Drinks: ['large', 'large', 'medium']
# drink: large
# drink: large
# drink: medium
# args (['olive'], ['ham', 'ham'], ['anchovy'])
# Pizza: ['olive']
# Pizza: ['ham', 'ham']
# Pizza: ['anchovy']
# Pizza Cost: 44.5
# Drinks: ['small', 'large']
# drink: small
# drink: large
# args (['pepperoni', 'anchovy', 'olive'], [], ['mushroom', 'pepperoni', 'olive'])
# Pizza: ['pepperoni', 'anchovy', 'olive']
# Pizza: []
# Pizza: ['mushroom', 'pepperoni', 'olive']
# Pizza Cost: 44.5
# Drinks: None
# args (['anchovy'], ['pepperoni'], [])
# Pizza: ['anchovy']
# Pizza: ['pepperoni']
# Pizza: []
# Pizza Cost: 42.0
# Drinks: ['small']
# drink: small
# args (['ham', 'pepperoni', 'anchovy'],)
# Pizza: ['ham', 'pepperoni', 'anchovy']
# Pizza Cost: 17.5
# Drinks: ['tub', 'medium', 'tub']
# drink: tub
# drink: medium
# drink: tub
# args ([], ['pepperoni', 'ham', 'anchovy'], [])
# Pizza: []
# Pizza: ['pepperoni', 'ham', 'anchovy']
# Pizza: []
# Pizza Cost: 43.5
# Drinks: None
# args ()
# Pizza Cost: 0.0
# Drinks: None
# args ()
# Pizza Cost: 0.0
# Drinks: ['tub', 'small', 'tub']
# drink: tub
# drink: small
# drink: tub
# args (['ham', 'ham', 'mushroom'], [])
# Pizza: ['ham', 'ham', 'mushroom']
# Pizza: []
# Pizza Cost: 29.5
# Drinks: ['large', 'small']
# drink: large
# drink: small
# args ([], ['olive', 'pepperoni'])
# Pizza: []
# Pizza: ['olive', 'pepperoni']
# Pizza Cost: 27.5
# Drinks: ['small']
# drink: small
# args (['anchovy', 'pepperoni', 'olive'], ['pepperoni'], [], [])
# Pizza: ['anchovy', 'pepperoni', 'olive']
# Pizza: ['pepperoni']
# Pizza: []
# Pizza: []
# Pizza Cost: 56.5
# Drinks: ['large']
# drink: large
# args (['ham'],)
# Pizza: ['ham']
# Pizza Cost: 14.5
# Drinks: ['large', 'large', 'large']
# drink: large
# drink: large
# drink: large
# args ([], ['olive', 'mushroom'], ['ham'])
# Pizza: []
# Pizza: ['olive', 'mushroom']
# Pizza: ['ham']
# Pizza Cost: 41.5
# Drinks: None
# args ([], ['olive'], [])
# Pizza: []
# Pizza: ['olive']
# Pizza: []
# Pizza Cost: 39.5
# Drinks: ['medium', 'medium']
# drink: medium
# drink: medium
# args ([],)
# Pizza: []
# Pizza Cost: 13.0
# Drinks: ['large']
# drink: large
# args (['mushroom', 'mushroom', 'anchovy'], ['olive'], ['ham'], [])
# Pizza: ['mushroom', 'mushroom', 'anchovy']
# Pizza: ['olive']
# Pizza: ['ham']
# Pizza: []
# Pizza Cost: 57.0
# Drinks: ['small']
# drink: small
# args ([], ['olive', 'anchovy'], [], ['olive', 'mushroom'])
# Pizza: []
# Pizza: ['olive', 'anchovy']
# Pizza: []
# Pizza: ['olive', 'mushroom']
# Pizza Cost: 55.5
# Drinks: ['tub']
# drink: tub
# args ()
# Pizza Cost: 0.0
# Drinks: ['tub', 'medium', 'medium']
# drink: tub
# drink: medium
# drink: medium
# args (['mushroom', 'ham'], ['olive', 'pepperoni'], ['ham', 'olive'])
# Pizza: ['mushroom', 'ham']
# Pizza: ['olive', 'pepperoni']
# Pizza: ['ham', 'olive']
# Pizza Cost: 44.5
# Drinks: ['small']
# drink: small
# args ()
# Pizza Cost: 0.0
# Drinks: ['tub']
# drink: tub
# args (['pepperoni', 'pepperoni', 'anchovy'], ['pepperoni'], ['anchovy'])
# Pizza: ['pepperoni', 'pepperoni', 'anchovy']
# Pizza: ['pepperoni']
# Pizza: ['anchovy']
# Pizza Cost: 46.0
# Drinks: ['tub', 'tub', 'tub']
# drink: tub
# drink: tub
# drink: tub
# args ([], ['pepperoni', 'mushroom', 'mushroom'], ['pepperoni'])
# Pizza: []
# Pizza: ['pepperoni', 'mushroom', 'mushroom']
# Pizza: ['pepperoni']
# Pizza Cost: 42.0
# Drinks: ['large', 'small', 'tub']
# drink: large
# drink: small
# drink: tub
# args (['olive', 'pepperoni', 'pepperoni'], ['olive', 'pepperoni', 'anchovy'], ['olive'], ['mushroom', 'pepperoni', 'mushroom'])
# Pizza: ['olive', 'pepperoni', 'pepperoni']
# Pizza: ['olive', 'pepperoni', 'anchovy']
# Pizza: ['olive']
# Pizza: ['mushroom', 'pepperoni', 'mushroom']
# Pizza Cost: 60.5
# Drinks: None
# args ()
# Pizza Cost: 0.0
# Drinks: None
# args ()
# Pizza Cost: 0.0
# Drinks: None
# args ([], ['pepperoni', 'mushroom', 'pepperoni'], ['pepperoni'])
# Pizza: []
# Pizza: ['pepperoni', 'mushroom', 'pepperoni']
# Pizza: ['pepperoni']
# Pizza Cost: 42.5
# Drinks: None
# args (['olive', 'ham'], ['olive', 'pepperoni'], ['olive', 'pepperoni', 'olive'], ['anchovy', 'ham'])
# Pizza: ['olive', 'ham']
# Pizza: ['olive', 'pepperoni']
# Pizza: ['olive', 'pepperoni', 'olive']
# Pizza: ['anchovy', 'ham']
# Pizza Cost: 61.0
# Drinks: ['large', 'small']
# drink: large
# drink: small
# args ([],)
# Pizza: []
# Pizza Cost: 13.0
# Drinks: ['tub']
# drink: tub
# args (['anchovy', 'ham', 'olive'], ['ham', 'ham'], ['olive', 'ham', 'ham'])
# Pizza: ['anchovy', 'ham', 'olive']
# Pizza: ['ham', 'ham']
# Pizza: ['olive', 'ham', 'ham']
# Pizza Cost: 49.5
# Drinks: ['tub']
# drink: tub
# args (['pepperoni', 'mushroom'], ['mushroom'], ['anchovy'])
# Pizza: ['pepperoni', 'mushroom']
# Pizza: ['mushroom']
# Pizza: ['anchovy']
# Pizza Cost: 43.0
# Drinks: None
# args (['anchovy', 'ham', 'olive'], ['ham', 'mushroom', 'ham'], [])
# Pizza: ['anchovy', 'ham', 'olive']
# Pizza: ['ham', 'mushroom', 'ham']
# Pizza: []
# Pizza Cost: 46.5
# Drinks: ['small']
# drink: small
# args (['pepperoni', 'anchovy', 'pepperoni'], [])
# Pizza: ['pepperoni', 'anchovy', 'pepperoni']
# Pizza: []
# Pizza Cost: 30.0
# Drinks: ['medium', 'large', 'medium']
# drink: medium
# drink: large
# drink: medium
# args ([], ['mushroom', 'olive', 'pepperoni'], ['olive', 'ham', 'anchovy'], ['mushroom', 'mushroom'])
# Pizza: []
# Pizza: ['mushroom', 'olive', 'pepperoni']
# Pizza: ['olive', 'ham', 'anchovy']
# Pizza: ['mushroom', 'mushroom']
# Pizza Cost: 59.0
# Drinks: ['small', 'large', 'medium']
# drink: small
# drink: large
# drink: medium
# args ([],)
# Pizza: []
# Pizza Cost: 13.0
# Drinks: ['tub', 'tub', 'large']
# drink: tub
# drink: tub
# drink: large
# args (['mushroom', 'mushroom', 'pepperoni'], ['anchovy'], ['olive', 'pepperoni', 'pepperoni'], ['pepperoni', 'mushroom'])
# Pizza: ['mushroom', 'mushroom', 'pepperoni']
# Pizza: ['anchovy']
# Pizza: ['olive', 'pepperoni', 'pepperoni']
# Pizza: ['pepperoni', 'mushroom']
# Pizza Cost: 60.0
# Drinks: ['small', 'tub', 'small']
# drink: small
# drink: tub
# drink: small
# args (['olive', 'olive'], [])
# Pizza: ['olive', 'olive']
# Pizza: []
# Pizza Cost: 27.0
# Drinks: None
# args (['mushroom'], ['ham', 'pepperoni'], ['anchovy'])
# Pizza: ['mushroom']
# Pizza: ['ham', 'pepperoni']
# Pizza: ['anchovy']
# Pizza Cost: 44.0
# Drinks: ['tub', 'medium']
# drink: tub
# drink: medium
# args (['anchovy'],)
# Pizza: ['anchovy']
# Pizza Cost: 15.0
# Drinks: None
# args (['pepperoni'], [])
# Pizza: ['pepperoni']
# Pizza: []
# Pizza Cost: 27.0
# Drinks: None
# args (['pepperoni', 'ham'],)
# Pizza: ['pepperoni', 'ham']
# Pizza Cost: 15.5
# Drinks: ['medium']
# drink: medium
# args (['olive'], ['ham'], ['anchovy'], ['mushroom'])
# Pizza: ['olive']
# Pizza: ['ham']
# Pizza: ['anchovy']
# Pizza: ['mushroom']
# Pizza Cost: 56.5
# Drinks: ['medium', 'medium']
# drink: medium
# drink: medium
# args ([], [], ['ham', 'anchovy'], ['pepperoni', 'mushroom', 'ham'])
# Pizza: []
# Pizza: []
# Pizza: ['ham', 'anchovy']
# Pizza: ['pepperoni', 'mushroom', 'ham']
# Pizza Cost: 58.5
# Drinks: ['small']
# drink: small
# args ([], ['pepperoni', 'anchovy'])
# Pizza: []
# Pizza: ['pepperoni', 'anchovy']
# Pizza Cost: 29.0
# Drinks: ['large', 'large']
# drink: large
# drink: large
# args ()
# Pizza Cost: 0.0
# Drinks: ['large', 'medium']
# drink: large
# drink: medium
# args (['ham'], [], [], [])
# Pizza: ['ham']
# Pizza: []
# Pizza: []
# Pizza: []
# Pizza Cost: 53.5
# Drinks: ['small', 'large', 'small']
# drink: small
# drink: large
# drink: small
# args ([], ['ham', 'pepperoni'], ['mushroom'], ['olive', 'olive', 'pepperoni'])
# Pizza: []
# Pizza: ['ham', 'pepperoni']
# Pizza: ['mushroom']
# Pizza: ['olive', 'olive', 'pepperoni']
# Pizza Cost: 57.0
# Drinks: None
# args (['anchovy', 'anchovy', 'ham'], ['pepperoni', 'olive'])
# Pizza: ['anchovy', 'anchovy', 'ham']
# Pizza: ['pepperoni', 'olive']
# Pizza Cost: 33.0
# Drinks: ['medium', 'large', 'small']
# drink: medium
# drink: large
# drink: small
# args ()
# Pizza Cost: 0.0
# Drinks: None
# args (['ham', 'ham'], ['anchovy', 'anchovy', 'mushroom'])
# Pizza: ['ham', 'ham']
# Pizza: ['anchovy', 'anchovy', 'mushroom']
# Pizza Cost: 33.5
# Drinks: ['tub', 'medium', 'medium']
# drink: tub
# drink: medium
# drink: medium
# args (['pepperoni', 'olive'], ['olive'])
# Pizza: ['pepperoni', 'olive']
# Pizza: ['olive']
# Pizza Cost: 28.0
# Drinks: None
# args (['olive', 'mushroom'], [], ['pepperoni', 'anchovy', 'anchovy'])
# Pizza: ['olive', 'mushroom']
# Pizza: []
# Pizza: ['pepperoni', 'anchovy', 'anchovy']
# Pizza Cost: 45.0
# Drinks: ['medium', 'tub', 'tub']
# drink: medium
# drink: tub
# drink: tub
# args (['olive', 'anchovy'],)
# Pizza: ['olive', 'anchovy']
# Pizza Cost: 15.5
# Drinks: None
# args ()
# Pizza Cost: 0.0
# Drinks: ['tub', 'medium', 'small']
# drink: tub
# drink: medium
# drink: small
# args ([], ['anchovy', 'anchovy'], ['anchovy', 'ham', 'olive'])
# Pizza: []
# Pizza: ['anchovy', 'anchovy']
# Pizza: ['anchovy', 'ham', 'olive']
# Pizza Cost: 47.0
# Drinks: ['medium', 'medium']
# drink: medium
# drink: medium
# args (['anchovy', 'ham', 'pepperoni'], ['mushroom', 'anchovy'], ['ham'], ['pepperoni', 'olive'])
# Pizza: ['anchovy', 'ham', 'pepperoni']
# Pizza: ['mushroom', 'anchovy']
# Pizza: ['ham']
# Pizza: ['pepperoni', 'olive']
# Pizza Cost: 62.0
# Drinks: None
# args ([], ['ham', 'mushroom'], ['ham', 'olive', 'mushroom'])
# Pizza: []
# Pizza: ['ham', 'mushroom']
# Pizza: ['ham', 'olive', 'mushroom']
# Pizza Cost: 43.5
# Drinks: ['large', 'tub', 'small']
# drink: large
# drink: tub
# drink: small
# args ([], [])
# Pizza: []
# Pizza: []
# Pizza Cost: 26.0
# Drinks: ['tub', 'small', 'small']
# drink: tub
# drink: small
# drink: small
# args (['anchovy', 'olive'], [], ['mushroom'])
# Pizza: ['anchovy', 'olive']
# Pizza: []
# Pizza: ['mushroom']
# Pizza Cost: 42.0
# Drinks: ['large']
# drink: large
# args (['ham', 'mushroom'],)
# Pizza: ['ham', 'mushroom']
# Pizza Cost: 15.0
# Drinks: ['medium']
# drink: medium
# args ([], [], ['mushroom'])
# Pizza: []
# Pizza: []
# Pizza: ['mushroom']
# Pizza Cost: 39.5
# Drinks: ['small', 'large', 'medium']
# drink: small
# drink: large
# drink: medium
# args ()
# Pizza Cost: 0.0
# Drinks: ['medium']
# drink: medium
# args ()
# Pizza Cost: 0.0
# Drinks: None
# args ()
# Pizza Cost: 0.0
# Drinks: ['small', 'small', 'medium']
# drink: small
# drink: small
# drink: medium
# args (['olive', 'anchovy'],)
# Pizza: ['olive', 'anchovy']
# Pizza Cost: 15.5
# Drinks: ['small', 'tub', 'medium']
# drink: small
# drink: tub
# drink: medium
# args (['pepperoni', 'mushroom'],)
# Pizza: ['pepperoni', 'mushroom']
# Pizza Cost: 14.5
# Drinks: ['medium', 'medium']
# drink: medium
# drink: medium
# args (['anchovy', 'pepperoni', 'mushroom'], [])
# Pizza: ['anchovy', 'pepperoni', 'mushroom']
# Pizza: []
# Pizza Cost: 29.5
# Drinks: ['small', 'tub', 'small']
# drink: small
# drink: tub
# drink: small
# args ()
# Pizza Cost: 0.0
# Drinks: ['tub']
# drink: tub
# args ()
# Pizza Cost: 0.0
# Drinks: ['small']
# drink: small
# args (['mushroom', 'mushroom'], ['anchovy', 'pepperoni', 'ham'], ['anchovy', 'olive', 'mushroom'])
# Pizza: ['mushroom', 'mushroom']
# Pizza: ['anchovy', 'pepperoni', 'ham']
# Pizza: ['anchovy', 'olive', 'mushroom']
# Pizza Cost: 47.5
# Drinks: ['large', 'small', 'tub']
# drink: large
# drink: small
# drink: tub
# args (['ham', 'olive'], ['anchovy'], [])
# Pizza: ['ham', 'olive']
# Pizza: ['anchovy']
# Pizza: []
# Pizza Cost: 43.0
# Drinks: ['tub', 'tub']
# drink: tub
# drink: tub
# args ([], ['anchovy', 'pepperoni'], [])
# Pizza: []
# Pizza: ['anchovy', 'pepperoni']
# Pizza: []
# Pizza Cost: 42.0
# Drinks: ['medium', 'tub', 'tub']
# drink: medium
# drink: tub
# drink: tub
# args ([],)
# Pizza: []
# Pizza Cost: 13.0
# Drinks: ['tub']
# drink: tub
# args (['olive'], ['anchovy'])
# Pizza: ['olive']
# Pizza: ['anchovy']
# Pizza Cost: 28.5
# Drinks: None
# args (['mushroom', 'anchovy'], ['mushroom'], ['pepperoni', 'ham'])
# Pizza: ['mushroom', 'anchovy']
# Pizza: ['mushroom']
# Pizza: ['pepperoni', 'ham']
# Pizza Cost: 44.5
# Drinks: ['tub', 'tub', 'tub']
# drink: tub
# drink: tub
# drink: tub
# args (['pepperoni', 'anchovy'], ['olive'])
# Pizza: ['pepperoni', 'anchovy']
# Pizza: ['olive']
# Pizza Cost: 29.5
# Drinks: ['medium']
# drink: medium
# args (['ham'], ['pepperoni'], ['mushroom'], [])
# Pizza: ['ham']
# Pizza: ['pepperoni']
# Pizza: ['mushroom']
# Pizza: []
# Pizza Cost: 55.0
# Drinks: None
# args (['ham', 'pepperoni'], ['anchovy', 'olive', 'anchovy'], ['pepperoni', 'pepperoni', 'ham'], ['olive', 'ham'])
# Pizza: ['ham', 'pepperoni']
# Pizza: ['anchovy', 'olive', 'anchovy']
# Pizza: ['pepperoni', 'pepperoni', 'ham']
# Pizza: ['olive', 'ham']
# Pizza Cost: 64.5
# Drinks: None
# args ()
# Pizza Cost: 0.0
# Drinks: None
# args (['anchovy', 'mushroom', 'ham'], ['mushroom', 'ham', 'mushroom'], ['ham', 'mushroom', 'olive'], ['anchovy'])
# Pizza: ['anchovy', 'mushroom', 'ham']
# Pizza: ['mushroom', 'ham', 'mushroom']
# Pizza: ['ham', 'mushroom', 'olive']
# Pizza: ['anchovy']
# Pizza Cost: 63.0
# Drinks: ['medium', 'medium', 'small']
# drink: medium
# drink: medium
# drink: small
# args ([], [], ['pepperoni'])
# Pizza: []
# Pizza: []
# Pizza: ['pepperoni']
# Pizza Cost: 40.0
# Drinks: ['tub', 'tub', 'medium']
# drink: tub
# drink: tub
# drink: medium
# args (['pepperoni', 'anchovy'], ['pepperoni', 'ham', 'ham'], ['mushroom', 'mushroom', 'anchovy'])
# Pizza: ['pepperoni', 'anchovy']
# Pizza: ['pepperoni', 'ham', 'ham']
# Pizza: ['mushroom', 'mushroom', 'anchovy']
# Pizza Cost: 49.0
# Drinks: ['small', 'medium', 'small']
# drink: small
# drink: medium
# drink: small
# args (['pepperoni', 'pepperoni'], ['ham', 'mushroom'])
# Pizza: ['pepperoni', 'pepperoni']
# Pizza: ['ham', 'mushroom']
# Pizza Cost: 30.0
# Drinks: None
# args ()
# Pizza Cost: 0.0
# Drinks: ['large']
# drink: large
# args (['olive'], ['mushroom', 'ham'], ['mushroom', 'pepperoni', 'anchovy'], ['olive'])
# Pizza: ['olive']
# Pizza: ['mushroom', 'ham']
# Pizza: ['mushroom', 'pepperoni', 'anchovy']
# Pizza: ['olive']
# Pizza Cost: 58.5
# Drinks: ['medium']
# drink: medium
# args (['anchovy', 'ham'],)
# Pizza: ['anchovy', 'ham']
# Pizza Cost: 16.5
# Drinks: ['large']
# drink: large
# args (['pepperoni'], ['mushroom'])
# Pizza: ['pepperoni']
# Pizza: ['mushroom']
# Pizza Cost: 27.5
# Drinks: ['medium']
# drink: medium
# args (['anchovy', 'anchovy', 'anchovy'],)
# Pizza: ['anchovy', 'anchovy', 'anchovy']
# Pizza Cost: 19.0
# Drinks: ['medium', 'small', 'medium']
# drink: medium
# drink: small
# drink: medium
# ...
# Pizza: []
# Pizza: ['pepperoni', 'ham']
# Pizza: ['anchovy', 'pepperoni', 'olive']
# Pizza: ['mushroom', 'olive']
# Pizza Cost: 59.0
# Drinks: ['large']
# drink: large
# args (['pepperoni'], [], ['olive'], ['mushroom', 'ham', 'ham'])
# Pizza: ['pepperoni']
# Pizza: []
# Pizza: ['olive']
# Pizza: ['mushroom', 'ham', 'ham']
# Pizza Cost: 57.0
# Drinks: ['medium', 'tub', 'large']
# drink: medium
# drink: tub
# drink: large
# args (['mushroom', 'mushroom'], ['olive', 'anchovy'])
# Pizza: ['mushroom', 'mushroom']
# Pizza: ['olive', 'anchovy']
# Pizza Cost: 29.5
# Drinks: ['large', 'small']
# drink: large
# drink: small
# args (['mushroom', 'ham'], ['ham', 'mushroom'], ['ham'])
# Pizza: ['mushroom', 'ham']
# Pizza: ['ham', 'mushroom']
# Pizza: ['ham']
# Pizza Cost: 44.5
# Drinks: ['medium', 'small']
# drink: medium
# drink: small
# args (['mushroom', 'mushroom', 'pepperoni'],)
# Pizza: ['mushroom', 'mushroom', 'pepperoni']
# Pizza Cost: 15.0
# Drinks: ['large', 'medium']
# drink: large
# drink: medium
# args (['anchovy', 'ham'], ['ham', 'ham'], ['pepperoni'], ['anchovy'])
# Pizza: ['anchovy', 'ham']
# Pizza: ['ham', 'ham']
# Pizza: ['pepperoni']
# Pizza: ['anchovy']
# Pizza Cost: 61.5
# Drinks: None
# args (['olive'],)
# Pizza: ['olive']
# Pizza Cost: 13.5
# Drinks: ['medium', 'large']
# drink: medium
# drink: large
# args ([],)
# Pizza: []
# Pizza Cost: 13.0
# Drinks: ['tub', 'large']
# drink: tub
# drink: large
# args ([],)
# Pizza: []
# Pizza Cost: 13.0
# Drinks: ['tub', 'large']
# drink: tub
# drink: large
# args ([], ['pepperoni', 'ham'], [])
# Pizza: []
# Pizza: ['pepperoni', 'ham']
# Pizza: []
# Pizza Cost: 41.5
# Drinks: ['large', 'large', 'small']
# drink: large
# drink: large
# drink: small
# args ([], ['pepperoni', 'ham'])
# Pizza: []
# Pizza: ['pepperoni', 'ham']
# Pizza Cost: 28.5
# Drinks: ['tub', 'small', 'medium']
# drink: tub
# drink: small
# drink: medium
# args (['pepperoni'], ['mushroom', 'olive', 'mushroom'], ['mushroom', 'mushroom', 'pepperoni'], ['pepperoni', 'ham', 'olive'])
# Pizza: ['pepperoni']
# Pizza: ['mushroom', 'olive', 'mushroom']
# Pizza: ['mushroom', 'mushroom', 'pepperoni']
# Pizza: ['pepperoni', 'ham', 'olive']
# Pizza Cost: 59.5
# Drinks: ['medium']
# drink: medium
# args (['ham'], ['pepperoni'])
# Pizza: ['ham']
# Pizza: ['pepperoni']
# Pizza Cost: 28.5
# Drinks: ['tub', 'large', 'medium']
# drink: tub
# drink: large
# drink: medium
# args (['ham', 'mushroom'], ['ham', 'olive'])
# Pizza: ['ham', 'mushroom']
# Pizza: ['ham', 'olive']
# Pizza Cost: 30.0
# Drinks: ['small', 'medium']
# drink: small
# drink: medium
# args (['ham', 'pepperoni', 'mushroom'], ['anchovy', 'mushroom', 'ham'], ['mushroom', 'ham', 'olive'])
# Pizza: ['ham', 'pepperoni', 'mushroom']
# Pizza: ['anchovy', 'mushroom', 'ham']
# Pizza: ['mushroom', 'ham', 'olive']
# Pizza Cost: 48.5
# Drinks: None
# args (['pepperoni', 'pepperoni'], ['pepperoni', 'pepperoni', 'pepperoni'], ['anchovy', 'ham', 'pepperoni'])
# Pizza: ['pepperoni', 'pepperoni']
# Pizza: ['pepperoni', 'pepperoni', 'pepperoni']
# Pizza: ['anchovy', 'ham', 'pepperoni']
# Pizza Cost: 48.5
# Drinks: ['medium', 'tub', 'small']
# drink: medium
# drink: tub
# drink: small
# args ()
# Pizza Cost: 0.0
# Drinks: ['large', 'tub']
# drink: large
# drink: tub
# args ()
# Pizza Cost: 0.0
# Drinks: None
# args (['olive', 'olive'],)
# Pizza: ['olive', 'olive']
# Pizza Cost: 14.0
# Drinks: ['large', 'large', 'large']
# drink: large
# drink: large
# drink: large
# args (['anchovy'], ['pepperoni', 'pepperoni'], [])
# Pizza: ['anchovy']
# Pizza: ['pepperoni', 'pepperoni']
# Pizza: []
# Pizza Cost: 43.0
# Drinks: ['small', 'small', 'tub']
# drink: small
# drink: small
# drink: tub
# args (['pepperoni'], [], ['olive', 'pepperoni', 'ham'])
# Pizza: ['pepperoni']
# Pizza: []
# Pizza: ['olive', 'pepperoni', 'ham']
# Pizza Cost: 43.0
# Drinks: ['tub', 'medium', 'medium']
# drink: tub
# drink: medium
# drink: medium
# args ([], ['olive'])
# Pizza: []
# Pizza: ['olive']
# Pizza Cost: 26.5
# Drinks: ['tub', 'small']
# drink: tub
# drink: small
# args ([], ['mushroom', 'ham'], ['olive', 'olive'])
# Pizza: []
# Pizza: ['mushroom', 'ham']
# Pizza: ['olive', 'olive']
# Pizza Cost: 42.0
# Drinks: ['large']
# drink: large
# args (['mushroom', 'pepperoni'],)
# Pizza: ['mushroom', 'pepperoni']
# Pizza Cost: 14.5
# Drinks: ['large', 'small']
# drink: large
# drink: small
# args (['pepperoni'],)
# Pizza: ['pepperoni']
# Pizza Cost: 14.0
# Drinks: ['large', 'medium']
# drink: large
# drink: medium
# args (['ham', 'mushroom', 'olive'], ['ham', 'olive'], ['ham', 'pepperoni'])
# Pizza: ['ham', 'mushroom', 'olive']
# Pizza: ['ham', 'olive']
# Pizza: ['ham', 'pepperoni']
# Pizza Cost: 46.0
# Drinks: None
# args ([], [], ['pepperoni'])
# Pizza: []
# Pizza: []
# Pizza: ['pepperoni']
# Pizza Cost: 40.0
# Drinks: ['medium', 'small']
# drink: medium
# drink: small
# args ()
# Pizza Cost: 0.0
# Drinks: ['small', 'tub']
# drink: small
# drink: tub
# args (['olive'], ['ham', 'mushroom'])
# Pizza: ['olive']
# Pizza: ['ham', 'mushroom']
# Pizza Cost: 28.5
# Drinks: None
# args ()
# Pizza Cost: 0.0
# Drinks: ['tub', 'large', 'small']
# drink: tub
# drink: large
# drink: small
# args (['ham', 'pepperoni'], ['mushroom', 'anchovy'], ['ham', 'ham'], ['ham'])
# Pizza: ['ham', 'pepperoni']
# Pizza: ['mushroom', 'anchovy']
# Pizza: ['ham', 'ham']
# Pizza: ['ham']
# Pizza Cost: 61.5
# Drinks: ['small']
# drink: small
# args (['anchovy'],)
# Pizza: ['anchovy']
# Pizza Cost: 15.0
# Drinks: None
# args ([],)
# Pizza: []
# Pizza Cost: 13.0
# Drinks: ['large', 'large', 'small']
# drink: large
# drink: large
# drink: small
# args (['ham'], ['pepperoni'])
# Pizza: ['ham']
# Pizza: ['pepperoni']
# Pizza Cost: 28.5
# Drinks: ['large', 'large', 'small']
# drink: large
# drink: large
# drink: small
# args (['olive', 'ham'], ['anchovy', 'ham'], ['olive'])
# Pizza: ['olive', 'ham']
# Pizza: ['anchovy', 'ham']
# Pizza: ['olive']
# Pizza Cost: 45.0
# Drinks: ['tub']
# drink: tub
# args ([], ['olive'], ['pepperoni', 'ham', 'olive'])
# Pizza: []
# Pizza: ['olive']
# Pizza: ['pepperoni', 'ham', 'olive']
# Pizza Cost: 42.5
# Drinks: ['large', 'large', 'medium']
# drink: large
# drink: large
# drink: medium
# args (['mushroom', 'mushroom'], ['anchovy', 'ham'])
# Pizza: ['mushroom', 'mushroom']
# Pizza: ['anchovy', 'ham']
# Pizza Cost: 30.5
# Drinks: None
# args ()
# Pizza Cost: 0.0
# Drinks: ['large']
# drink: large
# args ()
# Pizza Cost: 0.0
# Drinks: ['tub']
# drink: tub
# args (['mushroom', 'olive', 'olive'], ['ham', 'pepperoni', 'pepperoni'], ['mushroom', 'mushroom', 'anchovy'])
# Pizza: ['mushroom', 'olive', 'olive']
# Pizza: ['ham', 'pepperoni', 'pepperoni']
# Pizza: ['mushroom', 'mushroom', 'anchovy']
# Pizza Cost: 47.0
# Drinks: None
# args ([], ['mushroom', 'mushroom'], ['ham'], ['anchovy', 'olive', 'ham'])
# Pizza: []
# Pizza: ['mushroom', 'mushroom']
# Pizza: ['ham']
# Pizza: ['anchovy', 'olive', 'ham']
# Pizza Cost: 58.5
# Drinks: ['small']
# drink: small
# args (['anchovy', 'olive'], [])
# Pizza: ['anchovy', 'olive']
# Pizza: []
# Pizza Cost: 28.5
# Drinks: ['medium', 'small']
# drink: medium
# drink: small
# args (['olive'],)
# Pizza: ['olive']
# Pizza Cost: 13.5
# Drinks: None
# args (['ham', 'mushroom'], ['mushroom', 'pepperoni', 'anchovy'])
# Pizza: ['ham', 'mushroom']
# Pizza: ['mushroom', 'pepperoni', 'anchovy']
# Pizza Cost: 31.5
# Drinks: None
# args ([], ['pepperoni'], [], ['mushroom', 'ham', 'anchovy'])
# Pizza: []
# Pizza: ['pepperoni']
# Pizza: []
# Pizza: ['mushroom', 'ham', 'anchovy']
# Pizza Cost: 57.0
# Drinks: ['large']
# drink: large
# args (['mushroom', 'anchovy'], [], ['anchovy', 'pepperoni', 'olive'])
# Pizza: ['mushroom', 'anchovy']
# Pizza: []
# Pizza: ['anchovy', 'pepperoni', 'olive']
# Pizza Cost: 45.0
# Drinks: ['small', 'small']
# drink: small
# drink: small
# args (['olive', 'anchovy'],)
# Pizza: ['olive', 'anchovy']
# Pizza Cost: 15.5
# Drinks: ['tub', 'tub']
# drink: tub
# drink: tub
# args (['olive', 'anchovy', 'ham'], ['pepperoni', 'ham', 'pepperoni'], [], [])
# Pizza: ['olive', 'anchovy', 'ham']
# Pizza: ['pepperoni', 'ham', 'pepperoni']
# Pizza: []
# Pizza: []
# Pizza Cost: 59.5
# Drinks: ['tub', 'small', 'small']
# drink: tub
# drink: small
# drink: small
# args ([], [])
# Pizza: []
# Pizza: []
# Pizza Cost: 26.0
# Drinks: ['medium']
# drink: medium
# args (['anchovy', 'anchovy', 'anchovy'], [])
# Pizza: ['anchovy', 'anchovy', 'anchovy']
# Pizza: []
# Pizza Cost: 32.0
# Drinks: ['medium']
# drink: medium
# args (['olive', 'olive'], ['ham'])
# Pizza: ['olive', 'olive']
# Pizza: ['ham']
# Pizza Cost: 28.5
# Drinks: ['medium', 'large']
# drink: medium
# drink: large
# args ([], ['olive'], ['ham', 'pepperoni'], ['mushroom', 'ham', 'pepperoni'])
# Pizza: []
# Pizza: ['olive']
# Pizza: ['ham', 'pepperoni']
# Pizza: ['mushroom', 'ham', 'pepperoni']
# Pizza Cost: 58.0
# Drinks: ['medium', 'tub', 'small']
# drink: medium
# drink: tub
# drink: small
# args (['anchovy'], ['olive', 'mushroom'], [])
# Pizza: ['anchovy']
# Pizza: ['olive', 'mushroom']
# Pizza: []
# Pizza Cost: 42.0
# Drinks: None
# args (['mushroom', 'anchovy'], ['anchovy', 'olive'], ['pepperoni', 'ham', 'pepperoni'], ['ham'])
# Pizza: ['mushroom', 'anchovy']
# Pizza: ['anchovy', 'olive']
# Pizza: ['pepperoni', 'ham', 'pepperoni']
# Pizza: ['ham']
# Pizza Cost: 62.0
# Drinks: ['tub', 'medium']
# drink: tub
# drink: medium
# args ()
# Pizza Cost: 0.0
# Drinks: None
# args (['mushroom'], ['pepperoni', 'ham'])
# Pizza: ['mushroom']
# Pizza: ['pepperoni', 'ham']
# Pizza Cost: 29.0
# Drinks: None
# args (['pepperoni', 'mushroom'], [], ['ham', 'olive'], ['anchovy'])
# Pizza: ['pepperoni', 'mushroom']
# Pizza: []
# Pizza: ['ham', 'olive']
# Pizza: ['anchovy']
# Pizza Cost: 57.5
# Drinks: ['medium']
# drink: medium
# args ()
# Pizza Cost: 0.0
# Drinks: ['medium']
# drink: medium
# args (['pepperoni'],)
# Pizza: ['pepperoni']
# Pizza Cost: 14.0
# Drinks: None
# args ([],)
# Pizza: []
# Pizza Cost: 13.0
# Drinks: ['large']
# drink: large
# args (['mushroom'], ['mushroom', 'ham', 'anchovy'])
# Pizza: ['mushroom']
# Pizza: ['mushroom', 'ham', 'anchovy']
# Pizza Cost: 30.5
# Drinks: ['large', 'medium', 'small']
# drink: large
# drink: medium
# drink: small
# args (['mushroom', 'ham', 'anchovy'], [])
# Pizza: ['mushroom', 'ham', 'anchovy']
# Pizza: []
# Pizza Cost: 30.0
# Drinks: None
# args (['anchovy', 'ham', 'anchovy'], [], ['ham'])
# Pizza: ['anchovy', 'ham', 'anchovy']
# Pizza: []
# Pizza: ['ham']
# Pizza Cost: 46.0
# Drinks: None
# args (['olive', 'mushroom'],)
# Pizza: ['olive', 'mushroom']
# Pizza Cost: 14.0
# Drinks: ['large', 'large', 'large']
# drink: large
# drink: large
# drink: large
# args ([], ['ham'], ['mushroom', 'ham', 'mushroom'])
# Pizza: []
# Pizza: ['ham']
# Pizza: ['mushroom', 'ham', 'mushroom']
# Pizza Cost: 43.0
# Drinks: ['medium', 'medium']
# drink: medium
# drink: medium
# args ([],)
# Pizza: []
# Pizza Cost: 13.0
# Drinks: ['medium', 'large', 'large']
# drink: medium
# drink: large
# drink: large
# args (['anchovy'],)
# Pizza: ['anchovy']
# Pizza Cost: 15.0
# Drinks: None
# args (['pepperoni', 'olive', 'mushroom'],)
# Pizza: ['pepperoni', 'olive', 'mushroom']
# Pizza Cost: 15.0
# Drinks: ['small']
# drink: small
# args (['mushroom', 'ham'],)
# Pizza: ['mushroom', 'ham']
# Pizza Cost: 15.0
# Drinks: None
# args (['pepperoni'], ['olive'], ['mushroom'])
# Pizza: ['pepperoni']
# Pizza: ['olive']
# Pizza: ['mushroom']
# Pizza Cost: 41.0
# Drinks: ['tub', 'medium', 'small']
# drink: tub
# drink: medium
# drink: small
# args (['olive', 'olive', 'anchovy'], ['pepperoni', 'pepperoni'], ['mushroom', 'olive', 'mushroom'])
# Pizza: ['olive', 'olive', 'anchovy']
# Pizza: ['pepperoni', 'pepperoni']
# Pizza: ['mushroom', 'olive', 'mushroom']
# Pizza Cost: 45.5
# Drinks: None
# args ()
# Pizza Cost: 0.0
# Drinks: ['large']
# drink: large
# args (['pepperoni', 'pepperoni', 'anchovy'], ['olive'], [])
# Pizza: ['pepperoni', 'pepperoni', 'anchovy']
# Pizza: ['olive']
# Pizza: []
# Pizza Cost: 43.5
# Drinks: None
# args ()
# Pizza Cost: 0.0
# Drinks: ['medium', 'medium', 'large']
# drink: medium
# drink: medium
# drink: large
# args ([], ['anchovy'], ['anchovy', 'pepperoni'])
# Pizza: []
# Pizza: ['anchovy']
# Pizza: ['anchovy', 'pepperoni']
# Pizza Cost: 44.0
# Drinks: None
# args ([], ['olive', 'mushroom'], ['mushroom', 'ham'], ['ham', 'mushroom'])
# Pizza: []
# Pizza: ['olive', 'mushroom']
# Pizza: ['mushroom', 'ham']
# Pizza: ['ham', 'mushroom']
# Pizza Cost: 57.0
# Drinks: ['tub', 'small']
# drink: tub
# drink: small
# args (['mushroom', 'anchovy'], [], [], ['olive', 'mushroom', 'pepperoni'])
# Pizza: ['mushroom', 'anchovy']
# Pizza: []
# Pizza: []
# Pizza: ['olive', 'mushroom', 'pepperoni']
# Pizza Cost: 56.5
# Drinks: None
# args ()
# Pizza Cost: 0.0
# Drinks: ['small']
# drink: small
# args (['ham', 'pepperoni'], ['ham', 'ham'])
# Pizza: ['ham', 'pepperoni']
# Pizza: ['ham', 'ham']
# Pizza Cost: 31.5
# Drinks: ['tub', 'tub']
# drink: tub
# drink: tub
# args (['anchovy', 'pepperoni', 'ham'], ['mushroom'], ['pepperoni'])
# Pizza: ['anchovy', 'pepperoni', 'ham']
# Pizza: ['mushroom']
# Pizza: ['pepperoni']
# Pizza Cost: 45.0
# Drinks: ['small']
# drink: small
# args ([], [])
# Pizza: []
# Pizza: []
# Pizza Cost: 26.0
# Drinks: ['tub', 'small']
# drink: tub
# drink: small
# args (['pepperoni'], [])
# Pizza: ['pepperoni']
# Pizza: []
# Pizza Cost: 27.0
# Drinks: ['large', 'large', 'large']
# drink: large
# drink: large
# drink: large
# args (['ham', 'pepperoni'], ['mushroom'], ['ham', 'ham'])
# Pizza: ['ham', 'pepperoni']
# Pizza: ['mushroom']
# Pizza: ['ham', 'ham']
# Pizza Cost: 45.0
# Drinks: ['large', 'small']
# drink: large
# drink: small
# args ()
# Pizza Cost: 0.0
# Drinks: ['tub', 'tub', 'tub']
# drink: tub
# drink: tub
# drink: tub
# args (['anchovy'],)
# Pizza: ['anchovy']
# Pizza Cost: 15.0
# Drinks: ['large', 'medium', 'small']
# drink: large
# drink: medium
# drink: small
# args (['olive', 'anchovy', 'ham'], [], ['anchovy', 'anchovy'], ['pepperoni', 'mushroom', 'olive'])
# Pizza: ['olive', 'anchovy', 'ham']
# Pizza: []
# Pizza: ['anchovy', 'anchovy']
# Pizza: ['pepperoni', 'mushroom', 'olive']
# Pizza Cost: 62.0
# Drinks: None
# args (['ham', 'pepperoni'], ['mushroom', 'olive', 'pepperoni'], [], ['pepperoni', 'olive', 'mushroom'])
# Pizza: ['ham', 'pepperoni']
# Pizza: ['mushroom', 'olive', 'pepperoni']
# Pizza: []
# Pizza: ['pepperoni', 'olive', 'mushroom']
# Pizza Cost: 58.5
# Drinks: None
# args (['anchovy', 'ham', 'olive'], ['mushroom', 'pepperoni', 'mushroom'], [], ['ham'])
# Pizza: ['anchovy', 'ham', 'olive']
# Pizza: ['mushroom', 'pepperoni', 'mushroom']
# Pizza: []
# Pizza: ['ham']
# Pizza Cost: 59.5
# Drinks: ['medium', 'medium', 'large']
# drink: medium
# drink: medium
# drink: large
# args ([], ['anchovy'], ['pepperoni', 'mushroom', 'anchovy'], ['olive', 'pepperoni', 'ham'])
# Pizza: []
# Pizza: ['anchovy']
# Pizza: ['pepperoni', 'mushroom', 'anchovy']
# Pizza: ['olive', 'pepperoni', 'ham']
# Pizza Cost: 60.5
# Drinks: ['medium', 'small']
# drink: medium
# drink: small
# args ([], ['olive', 'pepperoni'], [])
# Pizza: []
# Pizza: ['olive', 'pepperoni']
# Pizza: []
# Pizza Cost: 40.5
# Drinks: ['small', 'large', 'medium']
# drink: small
# drink: large
# drink: medium
# args (['mushroom', 'pepperoni', 'mushroom'], ['mushroom', 'ham', 'pepperoni'], [], ['anchovy'])
# Pizza: ['mushroom', 'pepperoni', 'mushroom']
# Pizza: ['mushroom', 'ham', 'pepperoni']
# Pizza: []
# Pizza: ['anchovy']
# Pizza Cost: 59.0
# Drinks: ['tub', 'large']
# drink: tub
# drink: large
# args (['mushroom', 'mushroom', 'ham'],)
# Pizza: ['mushroom', 'mushroom', 'ham']
# Pizza Cost: 15.5
# Drinks: ['small', 'tub']
# drink: small
# drink: tub
# args ()
# Pizza Cost: 0.0
# Drinks: ['tub']
# drink: tub
# args (['olive'], ['olive', 'olive'])
# Pizza: ['olive']
# Pizza: ['olive', 'olive']
# Pizza Cost: 27.5
# Drinks: ['medium']
# drink: medium
# args ([],)
# Pizza: []
# Pizza Cost: 13.0
# Drinks: None
# args ([], ['pepperoni', 'mushroom', 'ham'], ['ham', 'anchovy'], ['anchovy', 'ham', 'mushroom'])
# Pizza: []
# Pizza: ['pepperoni', 'mushroom', 'ham']
# Pizza: ['ham', 'anchovy']
# Pizza: ['anchovy', 'ham', 'mushroom']
# Pizza Cost: 62.5
# Drinks: ['large']
# drink: large
# args (['anchovy', 'ham'], ['pepperoni', 'mushroom', 'mushroom'], ['pepperoni', 'mushroom'], ['pepperoni', 'anchovy'])
# Pizza: ['anchovy', 'ham']
# Pizza: ['pepperoni', 'mushroom', 'mushroom']
# Pizza: ['pepperoni', 'mushroom']
# Pizza: ['pepperoni', 'anchovy']
# Pizza Cost: 62.0
# Drinks: None
# args ([], ['olive', 'mushroom', 'pepperoni'], ['pepperoni'])
# Pizza: []
# Pizza: ['olive', 'mushroom', 'pepperoni']
# Pizza: ['pepperoni']
# Pizza Cost: 42.0
# Drinks: None
# args (['anchovy', 'ham'], [], ['ham'])
# Pizza: ['anchovy', 'ham']
# Pizza: []
# Pizza: ['ham']
# Pizza Cost: 44.0
# Drinks: ['medium']
# drink: medium
# args ()
# Pizza Cost: 0.0
# Drinks: ['large', 'medium']
# drink: large
# drink: medium
# args ()
# Pizza Cost: 0.0
# Drinks: None
#
# ============================== ALL TESTS PASSED! ===============================
# Your submission code: bw376a5897c31ca763c949f9e3e3b48926ae5e8e0dfb0210f3f59d4485
# ================================================================================
